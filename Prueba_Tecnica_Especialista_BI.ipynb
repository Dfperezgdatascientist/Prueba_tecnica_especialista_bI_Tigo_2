# %% [markdown]
# <img src="Tigo_3.png" width="300" height="150" />
#
# # **Prueba Técnica - Caso de Negocio**
# ## Prueba Analítica: Especialista BI para Marketing
# ### Especialista BI:
#
# * Daniel Felipe Pérez Grajales . dfperezg@unal.edu.co<br>
#
# <br><br>
#
#
# ---
# <br>
#
# **Objetivo General:**
#
# Evaluar la capacidad del aspirante al cargo *Especialista BI para Marketing* para:
#
# 1.	Integrar múltiples fuentes de datos, diseñando una arquitectura eficiente de unificación de fuentes.
# 2.	Uso de SQL para extraer, organizar y analizar información
# 3.	Construir el funel de conversión completo a partir de bases N1 y N2 realizar análisis profundos. El candidato deberá implementar un proceso de ETL en Python como parte clave de la solución.
# 4.	Desarrollar visualizaciones gerenciales e identificar cuál estrategia de contacto es más efectiva.
#
#
# **Contexto:**
#
# Tigo Colombia ejecuta campañas multicanal para contactar prospectos y clientes a través de *Call Center*, *Email* y *SMS*. Cada canal tiene sus propias fuentes y características operativas. Con el fin de mejorar la eficiencia de estas estrategias, es necesario analizar el desempeño completo del *funnel de conversión*, desde el primer contacto (N1) hasta la acción final (N2) de un Emtelco, uno de los canales de venta.
#
# **Parte 1: Diseño de arquitectura de datos**
#
# Se simularán diferentes orígenes de datos para el ejercicio, como:
#
# *	**SQL Server:** Turnos de atención/contactabilidad del Call Center.<br>
# *	**Google Analytics (GA4):** Datos de comportamiento digital y e-commerce.<br>
# *	**Excel:** Seguimiento manual de campañas.<br>
# *	**Braze:** Registro de contactos y respuestas vía WhatsApp/email/SMS.<br>
#
#
# **Actividades esperadas del candidato**
#
# *	Diseñar una arquitectura lógica que permita integrar las fuentes de datos mencionadas.
# *	Definir herramientas de extracción, transformación y consolidación.
# *	Representar visualmente la arquitectura (puede ser en pptx, Miro, Notion, etc.).
#
# **Parte 2 – Análisis funnel de conversión**
#
# Fuentes de información
# Las bases serán compartidas en formatos simulados (CSV/Excel) y representan lo siguiente:
# Tenga en cuenta los siguientes conceptos:
# -	Calidad: Relación entre los registros con intención de compra en primera instancia y la cantidad total de registros
# -	Efectividad: Relación entre las ventas cerradas y los registros con intención de compra en primera instancia
# -	Calificados: Registros con intención de compra en primera instancia
# -	Contacto efectivo: Registro en el que se logró tener una conversación con el cliente
# -	Contacto más efectivo: Los resultados de la llamada se priorizan, si bien no siempre se logra tener contacto con el cliente, algunos códigos de resultado son más efectivos que otros, por ejemplo: Un buzón de voz es más efectivo es más efectivo que un tono muerto.
#
# ### **N1 – Base de Contactos Iniciales:** Contiene los registros de todos los usuarios contactados por el canal, junto con variables como fecha, intención de compra, entre otros. A continuación, la descripción de cada uno de los campos:
# *	Id Registro: Id único de identificación
# *	Telefono: Número de teléfono del cliente
# *	Id Oferta, Descripcion Oferta, Descripcion Opcional: Identificadores de medios y campañas
# *	Codigo de resultado: Estatus actual del contacto
# *	Fecha efectiva, Hora efectiva: Hora y Fecha del contacto más efectivo con el cliente, que puede ser o no un contacto efectivo
# *	Duracion: Duración de la llamada
# *	Fecha primer intento, Hora primer intento: Fecha y hora de la primera marcación.
# *	Negocio: Negocio de la pauta, es decir, el tipo de oferta que se comunica (Hogares o Pospago)
# *	Medio Pauta: Medio por el cual se lanzó la camapaña.
#
# ### **N2 – Base de Conversión Final:** Contiene información de las personas que en primera instancia parecían tener una intención de compra. A continuación, la descripción de cada uno de los campos:
# *	Piloto: Sirve para identificar la regional
# *	CodFinalizacion
# *	Nivel 1, 2, 3, 4: Sirve para darle nivel de profundidad a los diferentes códigos de resultado o código de finalización
# *	CodFinalizacion: Estatus actual del contacto
# *	Negocio: Negocio en el que se cierra la venta
#
#
# **Desarrollo de ETL en Python**
#
# *	Realizar todo el proceso de limpieza, unificación y enriquecimiento de las bases N1 y N2.
# *	Unir los datasets para trazar todo el funnel, desde contacto inicial hasta conversión.
# *	Crear campos adicionales que considere necesarios
#
# **Construcción del Funnel de Conversión Completo**
#
# Mapear el funnel desde N1 hasta N2 por cada canal.Calcular:<br>
#
# *	Tasas de conversión y calidad por medio.
# *	Tiempo promedio de llamada por medio.
# *	Volumen de clientes en cada nivel del funnel.
# *	Proponer otros indicadores y su respectivo análisis.
#
#
# **Visualización gerencial**
#
# Construir un dashboard o reporte visual con:<br>
#
# *	Funnel de conversión por canal.
# *	KPIs clave: tasa de conversión, tiempo de conversión, tasa de abandono.
# *	Comparación entre medios.
# *	Insights sobre desviaciones o comportamientos atípicos.
#
#
# **Análisis y recomendaciones**
#
# *	¿Dónde se pierden más clientes?
# *	¿Qué se puede optimizar o escalar?
# *	¿Qué estrategias deberían mantenerse, ajustarse o despriorizarse?
#
# **Entregables esperados:**
#
# *	Script Python con la ETL y documentación (etl_contactabilidad.py).
# *	Dataset final consolidado y limpio (funnel_consolidado.csv).
# *	Dashboard o visualización con análisis (Power BI, Excel o Jupyter).
# *	Informe ejecutivo o presentación con análisis y recomendaciones (reporte_gerencial.pptx o .pdf).
#
# **Parte 3 – Uso SQL**
#
# Para esta sección no es necesaria hacer presentación. **Solamente se requiere enviar su solución. Los datos en las tablas descritas a continuación, son de “libre creación”.**
# Evaluación SQL (Estándar)
#
# Sean las siguientes tablas de una base de datos de una corredora de propiedades:
# 1.	Arrendatario (RUT, Nombre, Apellido)
# 2.	Arrienda (RUT, Id_casa,Deuda) Ojo: Deuda >=0 (si es 0, no hay deuda)
# 3.	Teléfonos (RUT, Telefono)
# 4.	Dueño (RUT, Nombre, Apellido)
# 5.	Casa (Id_casa, RUT, Nro,Calle, Comuna)<br>
#
# Al respecto, conteste las siguientes preguntas construyendo las sentencias SQL que corresponda:<br>
#
# 1.	Los arrendatarios que arriendan la casa ubicada en la calle Carrera nº 1024, Santiago.
# 2.	¿Cuánto le deben a María Pérez?
# 3.	¿Cuál es la deuda total para cada dueño?
# 4.	Liste todas las personas de la base de datos
# 5.	Indique los dueños que poseen tres o más casas.
# 6.	Liste los dueños que tengan deudores en todas sus casas.
# 7.	Entregue estadísticas sobre los arrendatarios por casa. Entregue:
# •	El promedio.
# •	La varianza.
# •	El máximo.
# •	El mínimo.
# •	La moda.
# •	La mediana.
#
# **Evaluación PL/SQL (Oracle)**
#
# 1.	Explique la función NVL. ¿Es mejor usar un NVL que un Case When? Explique su respuesta.
# 2.	Explique la función Left Join. En que casos es mas relevante usar un Left Join, en vez de un Inner Join.
# 3.	Explique la función row_number() Over (Partition by … Order by…). Danos un ejemplo en el cual es funcional esta función.
# 4.	Explique que es un Cursor y cuando son Implícitos y Explícitos
# 5.	¿Crees que desde Oracle puedes crear una ETL y que sea funcional? Justifica tu respuesta
#
#
#
# <br><br>
#
# --------
#
# ### Solución Prueba

# %% [markdown]
# #### 0. Carga de Módulos

# %%
# Tratamiento de datos
# ==============================================================================
import numpy as np
import pandas as pd
import re
import datetime as dt
from sklearn.datasets import make_classification

# Gráficos
# ==============================================================================
import matplotlib.pyplot as plt

# # Preprocesado y modelado
# # ==============================================================================
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.calibration import calibration_curve
# from sklearn.calibration import CalibratedClassifierCV
# from sklearn.metrics import brier_score_loss
# from sklearn.metrics import classification_report
# from sklearn.impute import SimpleImputer
# from sklearn.preprocessing import LabelEncoder, OneHotEncoder
# from sklearn.compose import ColumnTransformer
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler

# #sklearn modules for Model Selection:
# # ==============================================================================
# from sklearn import svm, tree, linear_model, neighbors
# from sklearn import naive_bayes, ensemble, discriminant_analysis, gaussian_process
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
# import xgboost 
# from xgboost import XGBClassifier
# from sklearn.linear_model import LogisticRegression
# from sklearn.svm import SVC
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.naive_bayes import GaussianNB
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier

# #sklearn modules for Model Evaluation & Improvement: 
# # ============================================================================== 
# from sklearn.metrics import confusion_matrix, accuracy_score 
# from sklearn.metrics import f1_score, precision_score, recall_score, fbeta_score
# from statsmodels.stats.outliers_influence import variance_inflation_factor
# from sklearn.model_selection import cross_val_score
# from sklearn.model_selection import GridSearchCV
# from sklearn.model_selection import ShuffleSplit
# from sklearn.model_selection import KFold
# from sklearn import feature_selection
# from sklearn import model_selection
# from sklearn import metrics
# from sklearn.metrics import classification_report, precision_recall_curve
# from sklearn.metrics import auc, roc_auc_score, roc_curve
# from sklearn.metrics import make_scorer, recall_score, log_loss
# from sklearn.metrics import average_precision_score
# from sklearn.metrics import mean_squared_error

# # Importar Librerias
# import joblib
# import pycaret
# # import ClassificationExperiment and init the class
# from pycaret.classification import ClassificationExperiment
# # import ClassificationExperiment and init the class
# from pycaret.classification import ClassificationExperiment
# import shap
# import optuna


# Configuración warnings
# ==============================================================================
import warnings
warnings.filterwarnings('once')
warnings.simplefilter('ignore', (DeprecationWarning))
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('display.max_rows', 500)
pd.options.display.max_columns = 120

# %% [markdown]
# #### **Parte 1: Diseño de arquitectura de datos**
#
# Se simularán diferentes orígenes de datos para el ejercicio, como:
#
# *	**SQL Server:** Turnos de atención/contactabilidad del Call Center.<br>
# *	**Google Analytics (GA4):** Datos de comportamiento digital y e-commerce.<br>
# *	**Excel:** Seguimiento manual de campañas.<br>
# *	**Braze:** Registro de contactos y respuestas vía WhatsApp/email/SMS.<br>
#
#
# **Actividades esperadas del candidato**
#
# *	Diseñar una arquitectura lógica que permita integrar las fuentes de datos mencionadas.
# *	Definir herramientas de extracción, transformación y consolidación.
# *	Representar visualmente la arquitectura (puede ser en pptx, Miro, Notion, etc.).
#
# <br>
# <br>
#
# ![ETL](Arquitectura_ETL.png)

# %% [markdown]
# #### **Parte 2 – Análisis funnel de conversión**
#
# Fuentes de información
# Las bases serán compartidas en formatos simulados (CSV/Excel) y representan lo siguiente:
# Tenga en cuenta los siguientes conceptos:
# -	Calidad: Relación entre los registros con intención de compra en primera instancia y la cantidad total de registros
# -	Efectividad: Relación entre las ventas cerradas y los registros con intención de compra en primera instancia
# -	Calificados: Registros con intención de compra en primera instancia
# -	Contacto efectivo: Registro en el que se logró tener una conversación con el cliente
# -	Contacto más efectivo: Los resultados de la llamada se priorizan, si bien no siempre se logra tener contacto con el cliente, algunos códigos de resultado son más efectivos que otros, por ejemplo: Un buzón de voz es más efectivo es más efectivo que un tono muerto.
#
# **N1 – Base de Contactos Iniciales:** Contiene los registros de todos los usuarios contactados por el canal, junto con variables como fecha, intención de compra, entre otros. A continuación, la descripción de cada uno de los campos:
# *	Id Registro: Id único de identificación
# *	Telefono: Número de teléfono del cliente
# *	Id Oferta, Descripcion Oferta, Descripcion Opcional: Identificadores de medios y campañas
# *	Codigo de resultado: Estatus actual del contacto
# *	Fecha efectiva, Hora efectiva: Hora y Fecha del contacto más efectivo con el cliente, que puede ser o no un contacto efectivo
# *	Duracion: Duración de la llamada
# *	Fecha primer intento, Hora primer intento: Fecha y hora de la primera marcación.
# *	Negocio: Negocio de la pauta, es decir, el tipo de oferta que se comunica (Hogares o Pospago)
# *	Medio Pauta: Medio por el cual se lanzó la camapaña.
#
# **N2 – Base de Conversión Final:** Contiene información de las personas que en primera instancia parecían tener una intención de compra. A continuación, la descripción de cada uno de los campos:
# *	Piloto: Sirve para identificar la regional
# *	CodFinalizacion
# *	Nivel 1, 2, 3, 4: Sirve para darle nivel de profundidad a los diferentes códigos de resultado o código de finalización
# *	CodFinalizacion: Estatus actual del contacto
# *	Negocio: Negocio en el que se cierra la venta
#
#
# **Desarrollo de ETL en Python**
#
# *	Realizar todo el proceso de limpieza, unificación y enriquecimiento de las bases N1 y N2.
# *	Unir los datasets para trazar todo el funnel, desde contacto inicial hasta conversión.
# *	Crear campos adicionales que considere necesarios
#
# **Construcción del Funnel de Conversión Completo**
#
# Mapear el funnel desde N1 hasta N2 por cada canal.Calcular:<br>
#
# *	Tasas de conversión y calidad por medio.
# *	Tiempo promedio de llamada por medio.
# *	Volumen de clientes en cada nivel del funnel.
# *	Proponer otros indicadores y su respectivo análisis.
#
#
# **Visualización gerencial**
#
# Construir un dashboard o reporte visual con:<br>
#
# *	Funnel de conversión por canal.
# *	KPIs clave: tasa de conversión, tiempo de conversión, tasa de abandono.
# *	Comparación entre medios.
# *	Insights sobre desviaciones o comportamientos atípicos.
#
#
# **Análisis y recomendaciones**
#
# *	¿Dónde se pierden más clientes?
# *	¿Qué se puede optimizar o escalar?
# *	¿Qué estrategias deberían mantenerse, ajustarse o despriorizarse?
#
# **Entregables esperados:**
#
# *	Script Python con la ETL y documentación (etl_contactabilidad.py).
# *	Dataset final consolidado y limpio (funnel_consolidado.csv).
# *	Dashboard o visualización con análisis (Power BI, Excel o Jupyter).
# *	Informe ejecutivo o presentación con análisis y recomendaciones (reporte_gerencial.pptx o .pdf).

# %% [markdown]
# ### 2.ETL

# %% [markdown]
# ### 2.1 Manejo de Base de datos

# %% [markdown]
# Fuentes de información
# Las bases serán compartidas en formatos simulados (CSV/Excel) y representan lo siguiente:
# Tenga en cuenta los siguientes conceptos:
# -	Calidad: Relación entre los registros con intención de compra en primera instancia y la cantidad total de registros
# -	Efectividad: Relación entre las ventas cerradas y los registros con intención de compra en primera instancia
# -	Calificados: Registros con intención de compra en primera instancia
# -	Contacto efectivo: Registro en el que se logró tener una conversación con el cliente
# -	Contacto más efectivo: Los resultados de la llamada se priorizan, si bien no siempre se logra tener contacto con el cliente, algunos códigos de resultado son más efectivos que otros, por ejemplo: Un buzón de voz es más efectivo es más efectivo que un tono muerto.

# %% [markdown]
# ### Base de datos N1

# %%
df_n1= pd.read_csv(r'C:\Users\Daniel\Documents\GitHub\Bases\Base N1 202302.csv',sep='|')
print(df_n1.shape)
df_n1.head()
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_17824\3916534534.py:1: DtypeWarning: Columns (0,1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_n1= pd.read_csv(r'C:\Users\Daniel\Documents\GitHub\Bases\Base N1 202302.csv',sep='|')
# (351337, 22)
#                             Id Registro  Id Cliente    Telefono  \
# 0  6070ab7b-0074-459b-a6c6-d4c2cb016f0e  3057509302  3057509302
# 1  c7359101-eb34-4233-9612-d53157b67a3f  3016350349  3016350349
# 2  f1ced391-a412-4f23-b9c7-3ff3dc7778d0  3214803065  3214803065
# 3  0bc3f5fc-385f-4cf9-a2a1-8948c232acde  3016500264  3016500264
# 4  a99c99a5-43e8-42ae-97bb-7cb8e720d625  3005461137  3005461137
#
#          Nombre usuario                Id Oferta Descripcion Oferta  \
# 0          sauldhasjdha   Home-MFO_Lead_Form_123                NaN
# 1  30163503493016350349  Abandono Home Activator                NaN
# 2  32148030653214803065  Abandono Home Activator                NaN
# 3  30165002643016500264  Abandono Home Activator                NaN
# 4  30054611373005461137  Abandono Home Activator                NaN
#
#   Descripcion Opcional                       Codigo de resultado  \
# 0       google_sem_123                      ININ-WRAP-UP-TIMEOUT
# 1                  NaN                         ESTADO DEL PEDIDO
# 2                  NaN                     ININ-OUTBOUND-MACHINE
# 3                  NaN                 YA SE COMUNICARON  CON EL
# 4                  NaN  ININ-OUTBOUND-NUMBER_COULD_NOT_BE_DIALED
#
#   Fecha efectiva Hora efectiva     Duracion  \
# 0     2023-08-02      16:58:30  94636.00000
# 1     2023-08-15      21:24:58 176245.00000
# 2     2023-08-15      21:24:38          NaN
# 3     2023-08-15      21:28:20  80244.00000
# 4     2023-08-15      21:28:32    667.00000
#
#                                 Asesor         Jobname               Correo  \
# 0          saul.barrera@emtelco.com.co  UNE_TELLAMAGEN  email@sincorreo.com
# 1  mpatical@experiencia.emtelco.com.co  UNE_TELLAMAGEN     noemail@none.com
# 2                                  NaN  UNE_TELLAMAGEN     noemail@none.com
# 3  mpatical@experiencia.emtelco.com.co  UNE_TELLAMAGEN     noemail@none.com
# 4                                  NaN  UNE_TELLAMAGEN     noemail@none.com
#
#   DescSolicitudCliente Fecha primer intento Hora primer intento Gerencia  \
# 0                  NaN           2023-08-02            15:32:32  Digital
# 1                  NaN           2023-08-15            21:24:58  Digital
# 2                  NaN           2023-08-15            21:24:38  Digital
# 3                  NaN           2023-08-15            21:28:20  Digital
# 4                  NaN           2023-08-15            21:28:32  Digital
#
#    Negocio Fecha Registro Hora Registro              Medio Pauta
# 0  Hogares     2023/08/02      16:54:34                     SEM
# 1  Hogares     2023/08/15      21:24:37  Abandono Ecommerce Home
# 2  Hogares     2023/08/15      21:24:37  Abandono Ecommerce Home
# 3  Hogares     2023/08/15      21:24:38  Abandono Ecommerce Home
# 4  Hogares     2023/08/15      21:24:38  Abandono Ecommerce Home

# %%
df_n1['Id Registro'].nunique()
# Out:
# 339647

# %% [markdown]
# registros vacios

# %%
df_n1['Id Registro'].isna().value_counts()
# Out:
# Id Registro
# False    340237
# True      11100
# Name: count, dtype: int64

# %%
df_n1[(df_n1['Id Registro'].isna())].head(10)
# Out:
#      Id Registro  Id Cliente    Telefono        Nombre usuario  \
# 3848         NaN  3043818356  3043818356  30438183563043818356
# 3849         NaN  3155413923  3155413923  31554139233155413923
# 3852         NaN  3008536832  3008536832  30085368323008536832
# 3854         NaN  3046821234  3046821234  30468212343046821234
# 3856         NaN  3146380341  3146380341  31463803413146380341
# 3858         NaN  3136002079  3136002079  31360020793136002079
# 3859         NaN  3022268875  3022268875  30222688753022268875
# 3862         NaN  3244510034  3244510034  32445100343244510034
# 3864         NaN  3013575712  3013575712  30135757123013575712
# 3866         NaN  3005748185  3005748185  30057481853005748185
#
#                     Id Oferta Descripcion Oferta Descripcion Opcional  \
# 3848  Abandono Home Activator                NaN                  NaN
# 3849  Abandono Home Activator                NaN                  NaN
# 3852  Abandono Home Activator                NaN                  NaN
# 3854  Abandono Home Activator                NaN                  NaN
# 3856  Abandono Home Activator                NaN                  NaN
# 3858  Abandono Home Activator                NaN                  NaN
# 3859  Abandono Home Activator                NaN                  NaN
# 3862  Abandono Home Activator                NaN                  NaN
# 3864  Abandono Home Activator                NaN                  NaN
# 3866  Abandono Home Activator                NaN                  NaN
#
#      Codigo de resultado Fecha efectiva Hora efectiva  Duracion Asesor  \
# 3848                 NaN            NaN           NaN   1.00000    NaN
# 3849                 NaN            NaN           NaN   1.00000    NaN
# 3852                 NaN            NaN           NaN   1.00000    NaN
# 3854                 NaN            NaN           NaN   1.00000    NaN
# 3856                 NaN            NaN           NaN   1.00000    NaN
# 3858                 NaN            NaN           NaN   1.00000    NaN
# 3859                 NaN            NaN           NaN   1.00000    NaN
# 3862                 NaN            NaN           NaN   1.00000    NaN
# 3864                 NaN            NaN           NaN   1.00000    NaN
# 3866                 NaN            NaN           NaN   1.00000    NaN
#
#              Jobname            Correo DescSolicitudCliente  \
# 3848  UNE_TELLAMAGEN  noemail@none.com                  NaN
# 3849  UNE_TELLAMAGEN  noemail@none.com                  NaN
# 3852  UNE_TELLAMAGEN  noemail@none.com                  NaN
# 3854  UNE_TELLAMAGEN  noemail@none.com                  NaN
# 3856  UNE_TELLAMAGEN  noemail@none.com                  NaN
# 3858  UNE_TELLAMAGEN  noemail@none.com                  NaN
# 3859  UNE_TELLAMAGEN  noemail@none.com                  NaN
# 3862  UNE_TELLAMAGEN  noemail@none.com                  NaN
# 3864  UNE_TELLAMAGEN  noemail@none.com                  NaN
# 3866  UNE_TELLAMAGEN  noemail@none.com                  NaN
#
#      Fecha primer intento Hora primer intento Gerencia  Negocio  \
# 3848           2023-08-31            10:16:55  Digital  Hogares
# 3849           2023-08-31            10:17:16  Digital  Hogares
# 3852           2023-08-31            10:17:18  Digital  Hogares
# 3854           2023-08-31            10:17:25  Digital  Hogares
# 3856           2023-08-31            10:17:33  Digital  Hogares
# 3858           2023-08-31            10:17:40  Digital  Hogares
# 3859           2023-08-31            10:17:47  Digital  Hogares
# 3862           2023-08-31            10:18:04  Digital  Hogares
# 3864           2023-08-31            10:18:14  Digital  Hogares
# 3866           2023-08-31            10:18:20  Digital  Hogares
#
#      Fecha Registro Hora Registro              Medio Pauta
# 3848     2023/08/31      00:40:12  Abandono Ecommerce Home
# 3849     2023/08/31      00:40:12  Abandono Ecommerce Home
# 3852     2023/08/31      00:40:13  Abandono Ecommerce Home
# 3854     2023/08/31      00:40:14  Abandono Ecommerce Home
# 3856     2023/08/31      00:40:15  Abandono Ecommerce Home
# 3858     2023/08/31      00:40:15  Abandono Ecommerce Home
# 3859     2023/08/31      01:26:39  Abandono Ecommerce Home
# 3862     2023/08/31      01:26:41  Abandono Ecommerce Home
# 3864     2023/08/31      01:26:42  Abandono Ecommerce Home
# 3866     2023/08/31      01:26:43  Abandono Ecommerce Home

# %%
df_n1[df_n1['Id Registro']=='0e46990b-797b-4745-9a89-150e30c2da4f']
# Out:
#                                  Id Registro  Id Cliente    Telefono  \
# 279631  0e46990b-797b-4745-9a89-150e30c2da4f  3058236225  3058236225
# 281454  0e46990b-797b-4745-9a89-150e30c2da4f  3058236225  3058236225
#
#        Nombre usuario                        Id Oferta Descripcion Oferta  \
# 279631   MiguelMoreno  FB_POST_RMKBRAZE_39X55_NAL_A025                NaN
# 281454   MiguelMoreno  FB_POST_LALBRAZE_55X39_NAL_A025                NaN
#
#        Descripcion Opcional Codigo de resultado Fecha efectiva Hora efectiva  \
# 279631        Facebookleads      BLENDING MOVIL     2023-12-04      13:41:28
# 281454        Facebookleads      BLENDING MOVIL     2023-12-04      13:41:28
#
#           Duracion                               Asesor         Jobname  \
# 279631 97302.00000  mjarasal@experiencia.emtelco.com.co  UNE_TELLAMAGEN
# 281454 97302.00000  mjarasal@experiencia.emtelco.com.co  UNE_TELLAMAGEN
#
#                             Correo DescSolicitudCliente Fecha primer intento  \
# 279631  miguelysaimon405@gmail.com     2247358908789462           2023-12-04
# 281454  miguelysaimon405@gmail.com     1541842666571529           2023-12-04
#
#        Hora primer intento Gerencia  Negocio Fecha Registro Hora Registro  \
# 279631            13:41:28  Digital  Pospago     2023/12/04      13:16:23
# 281454            13:41:28  Digital  Pospago     2023/12/04      22:38:07
#
#        Medio Pauta
# 279631    Facebook
# 281454    Facebook

# %%
df_n1[df_n1['Id Registro']=='5c4d6a06-a24f-406b-8f19-cbf4f33084b7']
# Out:
#                                  Id Registro  Id Cliente    Telefono  \
# 266353  5c4d6a06-a24f-406b-8f19-cbf4f33084b7  3004804366  3004804366
# 266590  5c4d6a06-a24f-406b-8f19-cbf4f33084b7  3004804366  3004804366
#
#           Nombre usuario                        Id Oferta Descripcion Oferta  \
# 266353  CecilianoreyMeza  FB_POST_LALBRAZE_55X39_NAL_A025                NaN
# 266590  ClienteSinNombre          Abandono Home Activator                NaN
#
#        Descripcion Opcional                       Codigo de resultado  \
# 266353        Facebookleads  ININ-OUTBOUND-CAMPAIGN-RECYCLE-CANCELLED
# 266590                  NaN  ININ-OUTBOUND-CAMPAIGN-RECYCLE-CANCELLED
#
#        Fecha efectiva Hora efectiva      Duracion Asesor         Jobname  \
# 266353     2023-11-28      19:46:15 5424807.00000    NaN  UNE_TELLAMAGEN
# 266590     2023-11-28      19:46:15 5424807.00000    NaN  UNE_TELLAMAGEN
#
#                                       Correo DescSolicitudCliente  \
# 266353  noreidaceeciliamezapicalua@gmail.com      236936912592855
# 266590                                   NaN                  NaN
#
#        Fecha primer intento Hora primer intento Gerencia  Negocio  \
# 266353           2023-11-27            10:59:41  Digital  Pospago
# 266590           2023-11-27            10:59:41  Digital  Hogares
#
#        Fecha Registro Hora Registro              Medio Pauta
# 266353     2023/11/28      19:44:19                 Facebook
# 266590     2023/11/28      23:43:00  Abandono Ecommerce Home

# %%
df_n1.describe()
# Out:
#             Duracion
# count   346946.00000
# mean   1159179.29727
# std    2406428.68567
# min     -43170.00000
# 25%        280.00000
# 50%      64211.50000
# 75%    1323076.25000
# max   70065984.00000

# %% [markdown]
# **N1 – Base de Contactos Iniciales:** Contiene los registros de todos los usuarios contactados por el canal, junto con variables como fecha, intención de compra, entre otros. A continuación, la descripción de cada uno de los campos:
# *	Id Registro: Id único de identificación
# *	Telefono: Número de teléfono del cliente
# *	Id Oferta, Descripcion Oferta, Descripcion Opcional: Identificadores de medios y campañas
# *	Codigo de resultado: Estatus actual del contacto
# *	Fecha efectiva, Hora efectiva: Hora y Fecha del contacto más efectivo con el cliente, que puede ser o no un contacto efectivo
# *	Duracion: Duración de la llamada
# *	Fecha primer intento, Hora primer intento: Fecha y hora de la primera marcación.
# *	Negocio: Negocio de la pauta, es decir, el tipo de oferta que se comunica (Hogares o Pospago)
# *	Medio Pauta: Medio por el cual se lanzó la camapaña.

# %%
df_n1.dtypes
# Out:
# Id Registro              object
# Id Cliente               object
# Telefono                 object
# Nombre usuario           object
# Id Oferta                object
# Descripcion Oferta       object
# Descripcion Opcional     object
# Codigo de resultado      object
# Fecha efectiva           object
# Hora efectiva            object
# Duracion                float64
# Asesor                   object
# Jobname                  object
# Correo                   object
# DescSolicitudCliente     object
# Fecha primer intento     object
# Hora primer intento      object
# Gerencia                 object
# Negocio                  object
# Fecha Registro           object
# Hora Registro            object
# Medio Pauta              object
# dtype: object

# %% [markdown]
# ## limpieza de CALLID vacios

# %%
df_n1_etl_1=df_n1[~(df_n1['Id Registro'].isna())]# Quitamos callid vacios
df_n1_etl_1.rename(columns = {'Id Registro':'CALLID'}, inplace = True)
print(df_n1_etl_1.shape)
df_n1_etl_1.head()
# Out:
# (340237, 22)
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_17824\3356641604.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_n1_etl_1.rename(columns = {'Id Registro':'CALLID'}, inplace = True)
#                                  CALLID  Id Cliente    Telefono  \
# 0  6070ab7b-0074-459b-a6c6-d4c2cb016f0e  3057509302  3057509302
# 1  c7359101-eb34-4233-9612-d53157b67a3f  3016350349  3016350349
# 2  f1ced391-a412-4f23-b9c7-3ff3dc7778d0  3214803065  3214803065
# 3  0bc3f5fc-385f-4cf9-a2a1-8948c232acde  3016500264  3016500264
# 4  a99c99a5-43e8-42ae-97bb-7cb8e720d625  3005461137  3005461137
#
#          Nombre usuario                Id Oferta Descripcion Oferta  \
# 0          sauldhasjdha   Home-MFO_Lead_Form_123                NaN
# 1  30163503493016350349  Abandono Home Activator                NaN
# 2  32148030653214803065  Abandono Home Activator                NaN
# 3  30165002643016500264  Abandono Home Activator                NaN
# 4  30054611373005461137  Abandono Home Activator                NaN
#
#   Descripcion Opcional                       Codigo de resultado  \
# 0       google_sem_123                      ININ-WRAP-UP-TIMEOUT
# 1                  NaN                         ESTADO DEL PEDIDO
# 2                  NaN                     ININ-OUTBOUND-MACHINE
# 3                  NaN                 YA SE COMUNICARON  CON EL
# 4                  NaN  ININ-OUTBOUND-NUMBER_COULD_NOT_BE_DIALED
#
#   Fecha efectiva Hora efectiva     Duracion  \
# 0     2023-08-02      16:58:30  94636.00000
# 1     2023-08-15      21:24:58 176245.00000
# 2     2023-08-15      21:24:38          NaN
# 3     2023-08-15      21:28:20  80244.00000
# 4     2023-08-15      21:28:32    667.00000
#
#                                 Asesor         Jobname               Correo  \
# 0          saul.barrera@emtelco.com.co  UNE_TELLAMAGEN  email@sincorreo.com
# 1  mpatical@experiencia.emtelco.com.co  UNE_TELLAMAGEN     noemail@none.com
# 2                                  NaN  UNE_TELLAMAGEN     noemail@none.com
# 3  mpatical@experiencia.emtelco.com.co  UNE_TELLAMAGEN     noemail@none.com
# 4                                  NaN  UNE_TELLAMAGEN     noemail@none.com
#
#   DescSolicitudCliente Fecha primer intento Hora primer intento Gerencia  \
# 0                  NaN           2023-08-02            15:32:32  Digital
# 1                  NaN           2023-08-15            21:24:58  Digital
# 2                  NaN           2023-08-15            21:24:38  Digital
# 3                  NaN           2023-08-15            21:28:20  Digital
# 4                  NaN           2023-08-15            21:28:32  Digital
#
#    Negocio Fecha Registro Hora Registro              Medio Pauta
# 0  Hogares     2023/08/02      16:54:34                     SEM
# 1  Hogares     2023/08/15      21:24:37  Abandono Ecommerce Home
# 2  Hogares     2023/08/15      21:24:37  Abandono Ecommerce Home
# 3  Hogares     2023/08/15      21:24:38  Abandono Ecommerce Home
# 4  Hogares     2023/08/15      21:24:38  Abandono Ecommerce Home

# %%
import datetime
df_n1_etl_1['fecha_registro_2']=pd.to_datetime(df_n1_etl_1['Fecha Registro']+' '+df_n1_etl_1['Hora Registro'],format='%Y/%m/%d %H:%M:%S',errors='coerce')#datetime.date.today()
df_n1_etl_1['anio_mes'] = df_n1_etl_1['fecha_registro_2'].dt.strftime('%Y%m') 
df_n1_etl_1.head()
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_17824\3554611711.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_n1_etl_1['fecha_registro_2']=pd.to_datetime(df_n1_etl_1['Fecha Registro']+' '+df_n1_etl_1['Hora Registro'],format='%Y/%m/%d %H:%M:%S',errors='coerce')#datetime.date.today()
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_17824\3554611711.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_n1_etl_1['anio_mes'] = df_n1_etl_1['fecha_registro_2'].dt.strftime('%Y%m')
#                                  CALLID  Id Cliente    Telefono  \
# 0  6070ab7b-0074-459b-a6c6-d4c2cb016f0e  3057509302  3057509302
# 1  c7359101-eb34-4233-9612-d53157b67a3f  3016350349  3016350349
# 2  f1ced391-a412-4f23-b9c7-3ff3dc7778d0  3214803065  3214803065
# 3  0bc3f5fc-385f-4cf9-a2a1-8948c232acde  3016500264  3016500264
# 4  a99c99a5-43e8-42ae-97bb-7cb8e720d625  3005461137  3005461137
#
#          Nombre usuario                Id Oferta Descripcion Oferta  \
# 0          sauldhasjdha   Home-MFO_Lead_Form_123                NaN
# 1  30163503493016350349  Abandono Home Activator                NaN
# 2  32148030653214803065  Abandono Home Activator                NaN
# 3  30165002643016500264  Abandono Home Activator                NaN
# 4  30054611373005461137  Abandono Home Activator                NaN
#
#   Descripcion Opcional                       Codigo de resultado  \
# 0       google_sem_123                      ININ-WRAP-UP-TIMEOUT
# 1                  NaN                         ESTADO DEL PEDIDO
# 2                  NaN                     ININ-OUTBOUND-MACHINE
# 3                  NaN                 YA SE COMUNICARON  CON EL
# 4                  NaN  ININ-OUTBOUND-NUMBER_COULD_NOT_BE_DIALED
#
#   Fecha efectiva Hora efectiva     Duracion  \
# 0     2023-08-02      16:58:30  94636.00000
# 1     2023-08-15      21:24:58 176245.00000
# 2     2023-08-15      21:24:38          NaN
# 3     2023-08-15      21:28:20  80244.00000
# 4     2023-08-15      21:28:32    667.00000
#
#                                 Asesor         Jobname               Correo  \
# 0          saul.barrera@emtelco.com.co  UNE_TELLAMAGEN  email@sincorreo.com
# 1  mpatical@experiencia.emtelco.com.co  UNE_TELLAMAGEN     noemail@none.com
# 2                                  NaN  UNE_TELLAMAGEN     noemail@none.com
# 3  mpatical@experiencia.emtelco.com.co  UNE_TELLAMAGEN     noemail@none.com
# 4                                  NaN  UNE_TELLAMAGEN     noemail@none.com
#
#   DescSolicitudCliente Fecha primer intento Hora primer intento Gerencia  \
# 0                  NaN           2023-08-02            15:32:32  Digital
# 1                  NaN           2023-08-15            21:24:58  Digital
# 2                  NaN           2023-08-15            21:24:38  Digital
# 3                  NaN           2023-08-15            21:28:20  Digital
# 4                  NaN           2023-08-15            21:28:32  Digital
#
#    Negocio Fecha Registro Hora Registro              Medio Pauta  \
# 0  Hogares     2023/08/02      16:54:34                     SEM
# 1  Hogares     2023/08/15      21:24:37  Abandono Ecommerce Home
# 2  Hogares     2023/08/15      21:24:37  Abandono Ecommerce Home
# 3  Hogares     2023/08/15      21:24:38  Abandono Ecommerce Home
# 4  Hogares     2023/08/15      21:24:38  Abandono Ecommerce Home
#
#      fecha_registro_2 anio_mes
# 0 2023-08-02 16:54:34   202308
# 1 2023-08-15 21:24:37   202308
# 2 2023-08-15 21:24:37   202308
# 3 2023-08-15 21:24:38   202308
# 4 2023-08-15 21:24:38   202308

# %% [markdown]
# #### primer contcato

# %%
df_n1[df_n1['Id Registro']=='5c4d6a06-a24f-406b-8f19-cbf4f33084b7']
# Out:
#                                  Id Registro  Id Cliente    Telefono  \
# 266353  5c4d6a06-a24f-406b-8f19-cbf4f33084b7  3004804366  3004804366
# 266590  5c4d6a06-a24f-406b-8f19-cbf4f33084b7  3004804366  3004804366
#
#           Nombre usuario                        Id Oferta Descripcion Oferta  \
# 266353  CecilianoreyMeza  FB_POST_LALBRAZE_55X39_NAL_A025                NaN
# 266590  ClienteSinNombre          Abandono Home Activator                NaN
#
#        Descripcion Opcional                       Codigo de resultado  \
# 266353        Facebookleads  ININ-OUTBOUND-CAMPAIGN-RECYCLE-CANCELLED
# 266590                  NaN  ININ-OUTBOUND-CAMPAIGN-RECYCLE-CANCELLED
#
#        Fecha efectiva Hora efectiva      Duracion Asesor         Jobname  \
# 266353     2023-11-28      19:46:15 5424807.00000    NaN  UNE_TELLAMAGEN
# 266590     2023-11-28      19:46:15 5424807.00000    NaN  UNE_TELLAMAGEN
#
#                                       Correo DescSolicitudCliente  \
# 266353  noreidaceeciliamezapicalua@gmail.com      236936912592855
# 266590                                   NaN                  NaN
#
#        Fecha primer intento Hora primer intento Gerencia  Negocio  \
# 266353           2023-11-27            10:59:41  Digital  Pospago
# 266590           2023-11-27            10:59:41  Digital  Hogares
#
#        Fecha Registro Hora Registro              Medio Pauta
# 266353     2023/11/28      19:44:19                 Facebook
# 266590     2023/11/28      23:43:00  Abandono Ecommerce Home

# %% [markdown]
# ### nos quedamos con el primer contacto

# %%
df_n1_etl_2=df_n1_etl_1.sort_values(['CALLID','fecha_registro_2'],ascending=[True,True]).groupby('CALLID').head(1)
print(df_n1_etl_2.shape)
df_n1_etl_2[df_n1_etl_2['CALLID']=='5c4d6a06-a24f-406b-8f19-cbf4f33084b7']
# Out:
# (339647, 24)
#                                       CALLID  Id Cliente    Telefono  \
# 266353  5c4d6a06-a24f-406b-8f19-cbf4f33084b7  3004804366  3004804366
#
#           Nombre usuario                        Id Oferta Descripcion Oferta  \
# 266353  CecilianoreyMeza  FB_POST_LALBRAZE_55X39_NAL_A025                NaN
#
#        Descripcion Opcional                       Codigo de resultado  \
# 266353        Facebookleads  ININ-OUTBOUND-CAMPAIGN-RECYCLE-CANCELLED
#
#        Fecha efectiva Hora efectiva      Duracion Asesor         Jobname  \
# 266353     2023-11-28      19:46:15 5424807.00000    NaN  UNE_TELLAMAGEN
#
#                                       Correo DescSolicitudCliente  \
# 266353  noreidaceeciliamezapicalua@gmail.com      236936912592855
#
#        Fecha primer intento Hora primer intento Gerencia  Negocio  \
# 266353           2023-11-27            10:59:41  Digital  Pospago
#
#        Fecha Registro Hora Registro Medio Pauta    fecha_registro_2 anio_mes
# 266353     2023/11/28      19:44:19    Facebook 2023-11-28 19:44:19   202311

# %% [markdown]
# ### base de datos N2

# %%
df_n2= pd.read_csv(r'C:\Users\Daniel\Documents\GitHub\Bases\Base N2 LTC 202302.csv',sep='|')
print(df_n2.shape)
df_n2.head()
# Out:
# (87751, 19)
#                                  CALLID         ANI    Asesor  Duracion_Seg  \
# 0  12fd0b6c-8223-4515-a0a8-4dac84265645  3195739206  nbermude     378.00000
# 1  b11de158-f826-4ead-9e1a-636398997296  3142567235  cmejiavi     223.00000
# 2  4f953081-9399-478a-b53b-6c836462a498  3227432074  lcangonz     390.00000
# 3  44064ac0-8e36-4582-99cd-383abd9672d6  3145729057  ycobosro    1442.00000
# 4  12b68210-3796-4857-9f15-5e3d7de9dd67  3222662256  lusugaza     641.00000
#
#                      Piloto    Nivel1                              Nivel2  \
# 0  UNE_VTASCTCORIENTE_IN_01  NO VENTA                    NO HAY COBERTURA
# 1  UNE_VTASCTCORIENTE_IN_01  NO VENTA                    NO HAY COBERTURA
# 2  UNE_VTASCTCORIENTE_IN_01  NO VENTA                        VENTA FUTURA
# 3  UNE_VTASCTCORIENTE_IN_01  NO VENTA             LO PENSARA O CONSULTARA
# 4  UNE_VTASCTCORIENTE_IN_01  NO VENTA  NO SE AJUSTA A LAS CARACTERISTICAS
#
#   Nivel3  Nivel4                              CodFinalizacion    Estado  \
# 0    NaN     NaN                    NO_VENTA-NO_HAY_COBERTURA  Atendido
# 1    NaN     NaN                    NO_VENTA-NO_HAY_COBERTURA  Atendido
# 2    NaN     NaN                        NO_VENTA-VENTA_FUTURA  Atendido
# 3    NaN     NaN             NO_VENTA-LO_PENSARA_O_CONSULTARA  Atendido
# 4    NaN     NaN  NO_VENTA-NO_SE_AJUSTA_A_LAS_CARACTERISTICAS  Atendido
#
#         DNIS  Negocio     Fecha      Hora Linea   BU Gerencia Origen
# 0  571102003  Hogares  1/8/2023  11:08:07   LTC  LTC      LTC    LTC
# 1  571102003  Hogares  1/8/2023  14:59:23   LTC  LTC      LTC    LTC
# 2  571102003  Hogares  1/8/2023   9:15:20   LTC  LTC      LTC    LTC
# 3  571102003  Hogares  1/8/2023  19:26:12   LTC  LTC      LTC    LTC
# 4  571102003  Hogares  1/8/2023  18:09:19   LTC  LTC      LTC    LTC

# %%
df_n2['CALLID'].isna().value_counts()
# Out:
# CALLID
# False    87751
# Name: count, dtype: int64

# %%
df_n2['CALLID'].nunique()
# Out:
# 87743

# %%
df_n2['CALLID'].value_counts()
# Out:
# CALLID
# b6d40314-5ffb-44d7-a1e7-32d4c97ad885    2
# af6b405a-7bdd-43cd-88d2-93828b62b074    2
# d37da370-61cc-44e0-96db-84a7a9edbc62    2
# 5d896169-fa99-42b1-aecc-f3006a9a90e9    2
# 8e042a7b-7ff4-4a2c-81be-2411f7b43ada    2
#                                        ..
# 5f3e0e3e-7501-434f-8841-abbbc68cdd43    1
# fb92f52a-4274-4f68-b3a1-92a12552c28b    1
# f4716745-4289-4685-8fbf-d555cca6008d    1
# ed7c3155-622c-403f-b48f-83eb6a018c95    1
# f9f3a8c9-b748-46cb-b4c6-e52d0955821c    1
# Name: count, Length: 87743, dtype: int64

# %%
df_n1[df_n1['Id Registro']=='b6d40314-5ffb-44d7-a1e7-32d4c97ad885']
# Out:
#                                  Id Registro  Id Cliente    Telefono  \
# 202038  b6d40314-5ffb-44d7-a1e7-32d4c97ad885  3114597233  3114597233
#
#            Nombre usuario               Id Oferta  \
# 202038  JulioCsarLpezRuiz  Home Trio BTS Original
#
#                                        Descripcion Oferta  \
# 202038  sem/co-home-mkt_search_performance_home_triodi...
#
#        Descripcion Opcional Codigo de resultado Fecha efectiva Hora efectiva  \
# 202038               Portal      BLENDING MOVIL     2023-10-31      19:56:02
#
#            Duracion                               Asesor         Jobname  \
# 202038 365153.00000  bramirpo@experiencia.emtelco.com.co  UNE_TELLAMAGEN
#
#        Correo                               DescSolicitudCliente  \
# 202038    NaN  Cj0KCQjwy4KqBhD0ARIsAEbCt6hIXtqetNNTDItRHADlE4...
#
#        Fecha primer intento Hora primer intento Gerencia  Negocio  \
# 202038           2023-10-31            10:03:09  Digital  Hogares
#
#        Fecha Registro Hora Registro Medio Pauta
# 202038     2023/10/31      19:55:57        SEM

# %%
df_n2[df_n2['CALLID']=='b6d40314-5ffb-44d7-a1e7-32d4c97ad885']
# Out:
#                                      CALLID         ANI  \
# 43533  b6d40314-5ffb-44d7-a1e7-32d4c97ad885  6044317000
# 82109  b6d40314-5ffb-44d7-a1e7-32d4c97ad885  6044317000
#
#                            Asesor  Duracion_Seg                       Piloto  \
# 43533       NAZARET FLOREZ ARANGO      14.00000  CMV_DIGMOVILOCCIDENTE_IN_01
# 82109  JENNY BIBIANA MUNOZ CORTES     191.00000     CMV_DIGMOVILBOGOTA_IN_01
#
#                Nivel1   Nivel2                                      Nivel3  \
# 43533  OTRAS LLAMADAS  CUELGUE  SIN SEÑAL O SIN SALDO O SE DESCARGO EL CEL
# 82109           VENTA     NIT                                        HOGAR
#
#        Nivel4                                    CodFinalizacion    Estado  \
# 43533     NaN  OTRAS_LLAMADAS-CUELGUE-SIN_SEÑAL_O_SIN_SALDO_O...  Atendido
# 82109     NaN                                    VENTA_NIT_HOGAR  Atendido
#
#              DNIS  Negocio       Fecha      Hora Linea   BU Gerencia  \
# 43533  3114597233  Pospago  31/10/2023  20:02:07   NaN  NaN      NaN
# 82109  3114597233  Pospago  31/10/2023  20:01:00   NaN  NaN      NaN
#
#             Origen
# 43533  Desconocido
# 82109  Desconocido

# %%
import datetime
df_n2['fecha_2']=pd.to_datetime(df_n2['Fecha']+' '+df_n2['Hora'],format='%d/%m/%Y %H:%M:%S',errors='coerce')#datetime.date.today()
df_n2['anio_mes_2'] = df_n2['fecha_2'].dt.strftime('%Y%m') 
df_n2.head()
# Out:
#                                  CALLID         ANI    Asesor  Duracion_Seg  \
# 0  12fd0b6c-8223-4515-a0a8-4dac84265645  3195739206  nbermude     378.00000
# 1  b11de158-f826-4ead-9e1a-636398997296  3142567235  cmejiavi     223.00000
# 2  4f953081-9399-478a-b53b-6c836462a498  3227432074  lcangonz     390.00000
# 3  44064ac0-8e36-4582-99cd-383abd9672d6  3145729057  ycobosro    1442.00000
# 4  12b68210-3796-4857-9f15-5e3d7de9dd67  3222662256  lusugaza     641.00000
#
#                      Piloto    Nivel1                              Nivel2  \
# 0  UNE_VTASCTCORIENTE_IN_01  NO VENTA                    NO HAY COBERTURA
# 1  UNE_VTASCTCORIENTE_IN_01  NO VENTA                    NO HAY COBERTURA
# 2  UNE_VTASCTCORIENTE_IN_01  NO VENTA                        VENTA FUTURA
# 3  UNE_VTASCTCORIENTE_IN_01  NO VENTA             LO PENSARA O CONSULTARA
# 4  UNE_VTASCTCORIENTE_IN_01  NO VENTA  NO SE AJUSTA A LAS CARACTERISTICAS
#
#   Nivel3  Nivel4                              CodFinalizacion    Estado  \
# 0    NaN     NaN                    NO_VENTA-NO_HAY_COBERTURA  Atendido
# 1    NaN     NaN                    NO_VENTA-NO_HAY_COBERTURA  Atendido
# 2    NaN     NaN                        NO_VENTA-VENTA_FUTURA  Atendido
# 3    NaN     NaN             NO_VENTA-LO_PENSARA_O_CONSULTARA  Atendido
# 4    NaN     NaN  NO_VENTA-NO_SE_AJUSTA_A_LAS_CARACTERISTICAS  Atendido
#
#         DNIS  Negocio     Fecha      Hora Linea   BU Gerencia Origen  \
# 0  571102003  Hogares  1/8/2023  11:08:07   LTC  LTC      LTC    LTC
# 1  571102003  Hogares  1/8/2023  14:59:23   LTC  LTC      LTC    LTC
# 2  571102003  Hogares  1/8/2023   9:15:20   LTC  LTC      LTC    LTC
# 3  571102003  Hogares  1/8/2023  19:26:12   LTC  LTC      LTC    LTC
# 4  571102003  Hogares  1/8/2023  18:09:19   LTC  LTC      LTC    LTC
#
#               fecha_2 anio_mes_2
# 0 2023-08-01 11:08:07     202308
# 1 2023-08-01 14:59:23     202308
# 2 2023-08-01 09:15:20     202308
# 3 2023-08-01 19:26:12     202308
# 4 2023-08-01 18:09:19     202308

# %% [markdown]
# #### nos quedamos con el primer contacto

# %%
df_n2_etl_1=df_n2.sort_values(['CALLID','fecha_2'],ascending=[True,True]).groupby('CALLID').head(1)
df_n2_etl_1.rename(columns = {'Asesor':'Asesor_call','Negocio':'Negocio_call','Gerencia':'Gerencia_call'}, inplace = True)
print(df_n2_etl_1.shape)
df_n2_etl_1[df_n2_etl_1['CALLID']=='b6d40314-5ffb-44d7-a1e7-32d4c97ad885']
# Out:
# (87743, 21)
#                                      CALLID         ANI  \
# 82109  b6d40314-5ffb-44d7-a1e7-32d4c97ad885  6044317000
#
#                       Asesor_call  Duracion_Seg                    Piloto  \
# 82109  JENNY BIBIANA MUNOZ CORTES     191.00000  CMV_DIGMOVILBOGOTA_IN_01
#
#       Nivel1 Nivel2 Nivel3  Nivel4  CodFinalizacion    Estado        DNIS  \
# 82109  VENTA   NIT   HOGAR     NaN  VENTA_NIT_HOGAR  Atendido  3114597233
#
#       Negocio_call       Fecha      Hora Linea   BU Gerencia_call  \
# 82109      Pospago  31/10/2023  20:01:00   NaN  NaN           NaN
#
#             Origen             fecha_2 anio_mes_2
# 82109  Desconocido 2023-10-31 20:01:00     202310

# %%
df_n2_etl_1.describe()
# Out:
#                    ANI  Duracion_Seg  Nivel4                        fecha_2
# count      87743.00000   87743.00000 0.00000                          87743
# mean  5076995631.46170     629.59749     NaN  2023-10-16 11:41:43.329029120
# min      1082819.00000       0.00000     NaN            2023-08-01 07:43:58
# 25%   3188116756.50000     207.00000     NaN            2023-09-06 16:18:30
# 50%   6044317000.00000     469.00000     NaN            2023-10-18 10:10:33
# 75%   6044317000.00000     975.00000     NaN            2023-11-23 09:28:00
# max   6053073882.00000    6201.00000     NaN            2023-12-31 16:10:42
# std   1380320230.64333     522.09779     NaN                            NaN

# %% [markdown]
# **N2 – Base de Conversión Final:** Contiene información de las personas que en primera instancia parecían tener una intención de compra. A continuación, la descripción de cada uno de los campos:
# *	Piloto: Sirve para identificar la regional
# *	CodFinalizacion
# *	Nivel 1, 2, 3, 4: Sirve para darle nivel de profundidad a los diferentes códigos de resultado o código de finalización
# *	CodFinalizacion: Estatus actual del contacto
# *	Negocio: Negocio en el que se cierra la venta

# %%
df_n2_etl_1.dtypes
# Out:
# CALLID                     object
# ANI                         int64
# Asesor_call                object
# Duracion_Seg              float64
# Piloto                     object
# Nivel1                     object
# Nivel2                     object
# Nivel3                     object
# Nivel4                    float64
# CodFinalizacion            object
# Estado                     object
# DNIS                       object
# Negocio_call               object
# Fecha                      object
# Hora                       object
# Linea                      object
# BU                         object
# Gerencia_call              object
# Origen                     object
# fecha_2            datetime64[ns]
# anio_mes_2                 object
# dtype: object

# %% [markdown]
# #### Cruce de información

# %%
df_n1_etl_2.columns
# Out:
# Index(['CALLID', 'Id Cliente', 'Telefono', 'Nombre usuario', 'Id Oferta',
#        'Descripcion Oferta', 'Descripcion Opcional', 'Codigo de resultado',
#        'Fecha efectiva', 'Hora efectiva', 'Duracion', 'Asesor', 'Jobname',
#        'Correo', 'DescSolicitudCliente', 'Fecha primer intento',
#        'Hora primer intento', 'Gerencia', 'Negocio', 'Fecha Registro',
#        'Hora Registro', 'Medio Pauta', 'fecha_registro_2', 'anio_mes'],
#       dtype='object')

# %%
df_n2_etl_1.columns
# Out:
# Index(['CALLID', 'ANI', 'Asesor_call', 'Duracion_Seg', 'Piloto', 'Nivel1',
#        'Nivel2', 'Nivel3', 'Nivel4', 'CodFinalizacion', 'Estado', 'DNIS',
#        'Negocio_call', 'Fecha', 'Hora', 'Linea', 'BU', 'Gerencia_call',
#        'Origen', 'fecha_2', 'anio_mes_2'],
#       dtype='object')

# %%
BD_funnel_consol= df_n1_etl_2[['CALLID','Telefono', 'Nombre usuario', 'Id Oferta',
       'Descripcion Oferta', 'Descripcion Opcional', 'Codigo de resultado',
       'Fecha efectiva', 'Hora efectiva', 'Duracion', 'Asesor', 'Jobname',
       'Correo', 'DescSolicitudCliente', 'Fecha primer intento',
       'Hora primer intento', 'Gerencia', 'Negocio', 'Medio Pauta', 'fecha_registro_2', 'anio_mes']].merge(df_n2_etl_1[['CALLID', 'ANI', 'Asesor_call', 'Duracion_Seg', 'Piloto', 'Nivel1',
       'Nivel2', 'Nivel3', 'Nivel4', 'CodFinalizacion', 'Estado', 'DNIS','Negocio_call', 'Linea', 'BU', 'Gerencia_call', 'Origen','fecha_2', 'anio_mes_2']], on=['CALLID'],how='left')

print(BD_funnel_consol.shape)
BD_funnel_consol.head()
# Out:
# (339647, 39)
#     CALLID    Telefono         Nombre usuario               Id Oferta  \
# 0  2515240  3172127900     UsuarioMultioferta      Multiofertas Brand
# 1  2515241  3054004532  LuisFelipeSalgadoMarn  Home Trio BTS Original
# 2  2515242  3113336842     UsuarioMultioferta      Multiofertas Brand
# 3  2515243  3163739622              Valentina       Multioferta Brand
# 4  2515244  3197425550     UsuarioMultioferta      Multiofertas Brand
#
#                                   Descripcion Oferta Descripcion Opcional  \
# 0  sem/co-post-mkt_search_performance_pospago_mul...               search
# 1  sem/co-home-mkt_search_performance_home_triodi...               search
# 2  sem/co-post-mkt_search_performance_pospago_mul...               search
# 3  sem/co-post-mkt_search_performance_pospago_mul...               search
# 4  sem/co-post-mkt_search_performance_pospago_mul...               search
#
#           Codigo de resultado Fecha efectiva Hora efectiva  Duracion  \
# 0  Answering Machine Detected     2023-08-14      12:58:57  34.00000
# 1                     CUELGUE     2023-08-14      12:28:54  25.00000
# 2                     FACTURA     2023-08-14      11:56:59 183.00000
# 3              BLENDING MOVIL     2023-08-14      11:57:01 939.00000
# 4  Answering Machine Detected     2023-08-14      12:59:46  18.00000
#
#                 Asesor         Jobname Correo  \
# 0                  NaN  UNE_TELLAMAGEN    NaN
# 1  lmosqmos_tellamagen  UNE_TELLAMAGEN    NaN
# 2  lhernagr_tellamagen  UNE_TELLAMAGEN    NaN
# 3  ycanaver_tellamagen  UNE_TELLAMAGEN    NaN
# 4                  NaN  UNE_TELLAMAGEN    NaN
#
#                                 DescSolicitudCliente Fecha primer intento  \
# 0  Cj0KCQjwoeemBhCfARIsADR2QCvgkvrVBodA3LSKjpK2Nt...           2023-08-14
# 1  Cj0KCQjwoeemBhCfARIsADR2QCsdaiD7tx9vHLPnCjRXEn...           2023-08-14
# 2  Cj0KCQjwoeemBhCfARIsADR2QCsm4hrff2Um6tH9S023Fw...           2023-08-14
# 3  Cj0KCQjwoeemBhCfARIsADR2QCtuhWk-5dyWCS2XpEThw3...           2023-08-14
# 4  Cj0KCQjwoeemBhCfARIsADR2QCtN6mOC1kp9J_HKz1Iw3q...           2023-08-14
#
#   Hora primer intento Gerencia  Negocio Medio Pauta    fecha_registro_2  \
# 0            11:56:14  Digital  Pospago        SEM  2023-08-14 11:56:05
# 1            11:56:27  Digital  Hogares        SEM  2023-08-14 11:56:08
# 2            11:56:59  Digital  Pospago        SEM  2023-08-14 11:56:17
# 3            11:57:01  Digital  Pospago        SEM  2023-08-14 11:56:47
# 4            11:57:11  Digital  Pospago        SEM  2023-08-14 11:57:06
#
#   anio_mes  ANI Asesor_call  Duracion_Seg Piloto Nivel1 Nivel2 Nivel3  Nivel4  \
# 0   202308  NaN         NaN           NaN    NaN    NaN    NaN    NaN     NaN
# 1   202308  NaN         NaN           NaN    NaN    NaN    NaN    NaN     NaN
# 2   202308  NaN         NaN           NaN    NaN    NaN    NaN    NaN     NaN
# 3   202308  NaN         NaN           NaN    NaN    NaN    NaN    NaN     NaN
# 4   202308  NaN         NaN           NaN    NaN    NaN    NaN    NaN     NaN
#
#   CodFinalizacion Estado DNIS Negocio_call Linea   BU Gerencia_call Origen  \
# 0             NaN    NaN  NaN          NaN   NaN  NaN           NaN    NaN
# 1             NaN    NaN  NaN          NaN   NaN  NaN           NaN    NaN
# 2             NaN    NaN  NaN          NaN   NaN  NaN           NaN    NaN
# 3             NaN    NaN  NaN          NaN   NaN  NaN           NaN    NaN
# 4             NaN    NaN  NaN          NaN   NaN  NaN           NaN    NaN
#
#   fecha_2 anio_mes_2
# 0     NaT        NaN
# 1     NaT        NaN
# 2     NaT        NaN
# 3     NaT        NaN
# 4     NaT        NaN

# %%
BD_funnel_consol[~(BD_funnel_consol['CodFinalizacion'].isna())].head()
# Out:
#                                      CALLID    Telefono  \
# 32768  00002c00-79b6-47a4-b6fb-7352e9ca2e45  3216416942
# 32773  00016ff7-557c-42dd-b618-fd71dee3a67b  3103480142
# 32776  000203d9-4c67-4219-a36f-f3342c1ee6bf  3135820122
# 32780  0002df07-a31a-4145-bb78-d1eb7f2ea12c  3117060487
# 32783  0003e18b-5689-4578-8879-19789d233a49  3005475604
#
#                 Nombre usuario                   Id Oferta  \
# 32768       UsuarioMultioferta          Multiofertas Brand
# 32773  Sandrarociozapatacuevas  Home Internet Planes Hztal
# 32776              CarlosParra      Home Trio BTS Original
# 32780     31170604873117060487     Abandono Home Activator
# 32783                Francisco          ExclusivoOnline121
#
#                                       Descripcion Oferta Descripcion Opcional  \
# 32768  sem/co-post-mkt_search_performance_pospago_mul...               search
# 32773                                             Portal               Portal
# 32776  sem/co-home-mkt_search_performance_home_triodi...               Portal
# 32780                                                NaN                  NaN
# 32783                      sms/oto-home-lleva300_sms1pos                masiv
#
#         Codigo de resultado Fecha efectiva Hora efectiva      Duracion  \
# 32768        BLENDING MOVIL     2023-12-28      14:07:38  437438.00000
# 32773         BLENDING HOME     2023-10-27      11:31:28  392477.00000
# 32776         BLENDING HOME     2023-11-01      16:03:43 2173277.00000
# 32780  NO_VENTA-TARIFA_ALTA     2023-08-24      09:25:17 2452502.00000
# 32783         BLENDING HOME     2023-09-24      11:38:52 6852074.00000
#
#                                     Asesor         Jobname            Correo  \
# 32768  cariaszu@experiencia.emtelco.com.co  UNE_TELLAMAGEN               NaN
# 32773  mjarasal@experiencia.emtelco.com.co  UNE_TELLAMAGEN               NaN
# 32776              ycanaver@emtelco.com.co  UNE_TELLAMAGEN               NaN
# 32780  ehernase@experiencia.emtelco.com.co  UNE_TELLAMAGEN  noemail@none.com
# 32783   jlgarci@experiencia.emtelco.com.co  UNE_TELLAMAGEN               NaN
#
#                                     DescSolicitudCliente Fecha primer intento  \
# 32768  EAIaIQobChMIkr6y5uiygwMVhp1aBR0YjAchEAAYASAAEg...           2023-12-28
# 32773                                                NaN           2023-10-27
# 32776  CjwKCAjw7oeqBhBwEiwALyHLM3YnhItnEpoy2oRKVPoVnd...           2023-11-01
# 32780                                                NaN           2023-08-24
# 32783                                                NaN           2023-09-24
#
#       Hora primer intento        Gerencia  Negocio              Medio Pauta  \
# 32768            14:07:38         Digital  Pospago                     SEM
# 32773            11:31:28         Digital  Hogares                  Portal
# 32776            16:03:43         Digital  Hogares                     SEM
# 32780            09:25:17         Digital  Hogares  Abandono Ecommerce Home
# 32783            11:38:52  Medios Propios  Hogares                    Masiv
#
#          fecha_registro_2 anio_mes              ANI  \
# 32768 2023-12-28 14:07:36   202312 6044317000.00000
# 32773 2023-10-27 10:50:40   202310 6044317000.00000
# 32776 2023-11-01 16:03:01   202311 6044317000.00000
# 32780 2023-08-24 09:25:02   202308 6044317000.00000
# 32783 2023-09-24 11:38:50   202309 6044317000.00000
#
#                         Asesor_call  Duracion_Seg  \
# 32768  LUCY VANNESSA CAUSIL BENITEZ     334.00000
# 32773                      lherntap     299.00000
# 32776                      nbermude    2104.00000
# 32780                      jscortes     526.00000
# 32783                      lbarrosg    1377.00000
#
#                                Piloto    Nivel1        Nivel2  \
# 32768  CMV_DIGMOVILNOROCCIDENTE_IN_01  NO VENTA         CLARO
# 32773        UNE_VTASCTCORIENTE_IN_01  NO VENTA  VENTA FUTURA
# 32776   UNE_VTASCTCNOROCCIDENTE_IN_01     VENTA        TRIPLE
# 32780         UNE_VTASCTCBOGOTA_IN_01  NO VENTA   TARIFA ALTA
# 32783         UNE_VTASCTCBOGOTA_IN_01     VENTA        TRIPLE
#
#                         Nivel3  Nivel4  \
# 32768  LO PENSARA O CONSULTARA     NaN
# 32773                      NaN     NaN
# 32776                      NaN     NaN
# 32780                      NaN     NaN
# 32783                      NaN     NaN
#
#                               CodFinalizacion    Estado        DNIS  \
# 32768  NO_VENTA-CLARO-LO_PENSARA_O_CONSULTARA  Atendido  3216416942
# 32773                   NO_VENTA-VENTA_FUTURA  Atendido  3103480142
# 32776                            VENTA-TRIPLE  Atendido  3135820122
# 32780                    NO_VENTA-TARIFA_ALTA  Atendido  3117060487
# 32783                            VENTA-TRIPLE  Atendido  3005475604
#
#       Negocio_call Linea   BU Gerencia_call       Origen             fecha_2  \
# 32768      Pospago   NaN  NaN           NaN  Desconocido 2023-12-28 14:14:55
# 32773      Hogares   NaN  NaN           NaN  Desconocido 2023-10-27 11:38:00
# 32776      Hogares   NaN  NaN           NaN  Desconocido 2023-11-01 16:39:57
# 32780      Hogares   NaN  NaN           NaN  Desconocido 2023-08-24 10:06:10
# 32783      Hogares   NaN  NaN           NaN  Desconocido 2023-09-24 13:33:04
#
#       anio_mes_2
# 32768     202312
# 32773     202310
# 32776     202311
# 32780     202308
# 32783     202309

# %%
BD_funnel_consol_2= df_n1_etl_2[['CALLID','Telefono', 'Nombre usuario', 'Id Oferta',
       'Descripcion Oferta', 'Descripcion Opcional', 'Codigo de resultado',
       'Fecha efectiva', 'Hora efectiva', 'Duracion', 'Asesor', 'Jobname',
       'Correo', 'DescSolicitudCliente', 'Fecha primer intento',
       'Hora primer intento', 'Gerencia', 'Negocio', 'Medio Pauta', 'fecha_registro_2', 'anio_mes']].merge(df_n2_etl_1[['CALLID', 'ANI', 'Asesor_call', 'Duracion_Seg', 'Piloto', 'Nivel1',
       'Nivel2', 'Nivel3', 'Nivel4', 'CodFinalizacion', 'Estado', 'DNIS','Negocio_call', 'Linea', 'BU', 'Gerencia_call', 'Origen','fecha_2', 'anio_mes_2']], on=['CALLID'],how='inner')

print(BD_funnel_consol_2.shape)
BD_funnel_consol_2.head()
# Out:
# (54190, 39)
#                                  CALLID    Telefono           Nombre usuario  \
# 0  00002c00-79b6-47a4-b6fb-7352e9ca2e45  3216416942       UsuarioMultioferta
# 1  00016ff7-557c-42dd-b618-fd71dee3a67b  3103480142  Sandrarociozapatacuevas
# 2  000203d9-4c67-4219-a36f-f3342c1ee6bf  3135820122              CarlosParra
# 3  0002df07-a31a-4145-bb78-d1eb7f2ea12c  3117060487     31170604873117060487
# 4  0003e18b-5689-4578-8879-19789d233a49  3005475604                Francisco
#
#                     Id Oferta  \
# 0          Multiofertas Brand
# 1  Home Internet Planes Hztal
# 2      Home Trio BTS Original
# 3     Abandono Home Activator
# 4          ExclusivoOnline121
#
#                                   Descripcion Oferta Descripcion Opcional  \
# 0  sem/co-post-mkt_search_performance_pospago_mul...               search
# 1                                             Portal               Portal
# 2  sem/co-home-mkt_search_performance_home_triodi...               Portal
# 3                                                NaN                  NaN
# 4                      sms/oto-home-lleva300_sms1pos                masiv
#
#     Codigo de resultado Fecha efectiva Hora efectiva      Duracion  \
# 0        BLENDING MOVIL     2023-12-28      14:07:38  437438.00000
# 1         BLENDING HOME     2023-10-27      11:31:28  392477.00000
# 2         BLENDING HOME     2023-11-01      16:03:43 2173277.00000
# 3  NO_VENTA-TARIFA_ALTA     2023-08-24      09:25:17 2452502.00000
# 4         BLENDING HOME     2023-09-24      11:38:52 6852074.00000
#
#                                 Asesor         Jobname            Correo  \
# 0  cariaszu@experiencia.emtelco.com.co  UNE_TELLAMAGEN               NaN
# 1  mjarasal@experiencia.emtelco.com.co  UNE_TELLAMAGEN               NaN
# 2              ycanaver@emtelco.com.co  UNE_TELLAMAGEN               NaN
# 3  ehernase@experiencia.emtelco.com.co  UNE_TELLAMAGEN  noemail@none.com
# 4   jlgarci@experiencia.emtelco.com.co  UNE_TELLAMAGEN               NaN
#
#                                 DescSolicitudCliente Fecha primer intento  \
# 0  EAIaIQobChMIkr6y5uiygwMVhp1aBR0YjAchEAAYASAAEg...           2023-12-28
# 1                                                NaN           2023-10-27
# 2  CjwKCAjw7oeqBhBwEiwALyHLM3YnhItnEpoy2oRKVPoVnd...           2023-11-01
# 3                                                NaN           2023-08-24
# 4                                                NaN           2023-09-24
#
#   Hora primer intento        Gerencia  Negocio              Medio Pauta  \
# 0            14:07:38         Digital  Pospago                     SEM
# 1            11:31:28         Digital  Hogares                  Portal
# 2            16:03:43         Digital  Hogares                     SEM
# 3            09:25:17         Digital  Hogares  Abandono Ecommerce Home
# 4            11:38:52  Medios Propios  Hogares                    Masiv
#
#      fecha_registro_2 anio_mes         ANI                   Asesor_call  \
# 0 2023-12-28 14:07:36   202312  6044317000  LUCY VANNESSA CAUSIL BENITEZ
# 1 2023-10-27 10:50:40   202310  6044317000                      lherntap
# 2 2023-11-01 16:03:01   202311  6044317000                      nbermude
# 3 2023-08-24 09:25:02   202308  6044317000                      jscortes
# 4 2023-09-24 11:38:50   202309  6044317000                      lbarrosg
#
#    Duracion_Seg                          Piloto    Nivel1        Nivel2  \
# 0     334.00000  CMV_DIGMOVILNOROCCIDENTE_IN_01  NO VENTA         CLARO
# 1     299.00000        UNE_VTASCTCORIENTE_IN_01  NO VENTA  VENTA FUTURA
# 2    2104.00000   UNE_VTASCTCNOROCCIDENTE_IN_01     VENTA        TRIPLE
# 3     526.00000         UNE_VTASCTCBOGOTA_IN_01  NO VENTA   TARIFA ALTA
# 4    1377.00000         UNE_VTASCTCBOGOTA_IN_01     VENTA        TRIPLE
#
#                     Nivel3  Nivel4                         CodFinalizacion  \
# 0  LO PENSARA O CONSULTARA     NaN  NO_VENTA-CLARO-LO_PENSARA_O_CONSULTARA
# 1                      NaN     NaN                   NO_VENTA-VENTA_FUTURA
# 2                      NaN     NaN                            VENTA-TRIPLE
# 3                      NaN     NaN                    NO_VENTA-TARIFA_ALTA
# 4                      NaN     NaN                            VENTA-TRIPLE
#
#      Estado        DNIS Negocio_call Linea   BU Gerencia_call       Origen  \
# 0  Atendido  3216416942      Pospago   NaN  NaN           NaN  Desconocido
# 1  Atendido  3103480142      Hogares   NaN  NaN           NaN  Desconocido
# 2  Atendido  3135820122      Hogares   NaN  NaN           NaN  Desconocido
# 3  Atendido  3117060487      Hogares   NaN  NaN           NaN  Desconocido
# 4  Atendido  3005475604      Hogares   NaN  NaN           NaN  Desconocido
#
#               fecha_2 anio_mes_2
# 0 2023-12-28 14:14:55     202312
# 1 2023-10-27 11:38:00     202310
# 2 2023-11-01 16:39:57     202311
# 3 2023-08-24 10:06:10     202308
# 4 2023-09-24 13:33:04     202309

# %%
BD_funnel_consol.dtypes
# Out:
# CALLID                          object
# Telefono                        object
# Nombre usuario                  object
# Id Oferta                       object
# Descripcion Oferta              object
# Descripcion Opcional            object
# Codigo de resultado             object
# Fecha efectiva                  object
# Hora efectiva                   object
# Duracion                       float64
# Asesor                          object
# Jobname                         object
# Correo                          object
# DescSolicitudCliente            object
# Fecha primer intento            object
# Hora primer intento             object
# Gerencia                        object
# Negocio                         object
# Medio Pauta                     object
# fecha_registro_2        datetime64[ns]
# anio_mes                        object
# ANI                            float64
# Asesor_call                     object
# Duracion_Seg                   float64
# Piloto                          object
# Nivel1                          object
# Nivel2                          object
# Nivel3                          object
# Nivel4                         float64
# CodFinalizacion                 object
# Estado                          object
# DNIS                            object
# Negocio_call                    object
# Linea                           object
# BU                              object
# Gerencia_call                   object
# Origen                          object
# fecha_2                 datetime64[ns]
# anio_mes_2                      object
# dtype: object

# %% [markdown]
# ### Negocios donde se cierra la venta:

# %%
print(BD_funnel_consol['Negocio_call'].value_counts(dropna=False))
print()
print(BD_funnel_consol['Negocio_call'].value_counts(True,dropna=False)*100)
# Out:
# Negocio_call
# NaN        285457
# Pospago     32353
# Hogares     21837
# Name: count, dtype: int64
#
# Negocio_call
# NaN       84.04520
# Pospago    9.52548
# Hogares    6.42932
# Name: proportion, dtype: float64

# %% [markdown]
# ### Negocio primer contacto

# %%
print(BD_funnel_consol['Negocio'].value_counts(dropna=False))
print()
print(BD_funnel_consol['Negocio'].value_counts(True,dropna=False)*100)
# Out:
# Negocio
# Pospago    248172
# Hogares     91475
# Name: count, dtype: int64
#
# Negocio
# Pospago   73.06763
# Hogares   26.93237
# Name: proportion, dtype: float64

# %% [markdown]
# ### Medios de Pauta

# %%
print(BD_funnel_consol['Medio Pauta'].value_counts(dropna=False))
print()
print(BD_funnel_consol['Medio Pauta'].value_counts(True,dropna=False)*100)
# Out:
# Medio Pauta
# SEM                         205552
# Facebook                     58270
# Abandono Ecommerce Home      24570
# Masiv                        19640
# Portal                       11838
# Display                       6868
# Portal                        3514
# Walmeric                      2742
# Abandono Ecommerce Movil      2360
# Desborde IVR - Movil          1512
# Abandono VTEX                 1057
# Discovery                      607
# LeadGenios                     600
# Bot                            113
# YouTube                        109
# Instagram                       95
# Braze                           94
# Arkero                          40
# TikTok                          23
# DV360                           10
# Convertia                        6
# Desborde IVR - Home              5
# TapTap                           4
# Peoplemedia                      3
# Cmgroup_Home                     3
# Pruebas                          3
# tiktok                           3
# App                              3
# extwebsite                       1
# Pardot                           1
# El Tiempo                        1
# Name: count, dtype: int64
#
# Medio Pauta
# SEM                        60.51930
# Facebook                   17.15605
# Abandono Ecommerce Home     7.23398
# Masiv                       5.78247
# Portal                      3.48538
# Display                     2.02210
# Portal                      1.03460
# Walmeric                    0.80731
# Abandono Ecommerce Movil    0.69484
# Desborde IVR - Movil        0.44517
# Abandono VTEX               0.31121
# Discovery                   0.17871
# LeadGenios                  0.17665
# Bot                         0.03327
# YouTube                     0.03209
# Instagram                   0.02797
# Braze                       0.02768
# Arkero                      0.01178
# TikTok                      0.00677
# DV360                       0.00294
# Convertia                   0.00177
# Desborde IVR - Home         0.00147
# TapTap                      0.00118
# Peoplemedia                 0.00088
# Cmgroup_Home                0.00088
# Pruebas                     0.00088
# tiktok                      0.00088
# App                         0.00088
# extwebsite                  0.00029
# Pardot                      0.00029
# El Tiempo                   0.00029
# Name: proportion, dtype: float64

# %% [markdown]
# ### Construir medio de pauta pareto

# %%
import re
# Limpieza, carecteres especiales y signos de puntuacion
def limpieza_basica(body):
    body = body.lower()
    body = re.sub(" \d+",' ', body) #Eliminar numeros
    body = re.sub('[^a-z ]',' ', body) #quitar numeros dentro de palabras
    body = re.sub('\[#*.>=\]','',body) # Eliminar caracteres 
    #body = re.sub('[%s]' %re.escape(string.punctuation),' ', body) # Eliminar signos puntuacion
    body= re.sub(r"[\r\n]+",' ', body)
    body= re.compile(r'\bLiza\b').sub(' ', body)
    body=re.sub("\s\s+" , " ", body)
    body= body.strip()
    return body
limpiar = lambda x: limpieza_basica(x)

# %%
BD_funnel_consol['Medio_Pauta_2'] = BD_funnel_consol['Medio Pauta'].apply(limpiar)

# %%
print(BD_funnel_consol['Medio_Pauta_2'].value_counts(dropna=False))
print()
print(BD_funnel_consol['Medio_Pauta_2'].value_counts(True,dropna=False)*100)
# Out:
# Medio_Pauta_2
# sem                         205552
# facebook                     58270
# abandono ecommerce home      24570
# masiv                        19640
# portal                       15352
# display                       6868
# walmeric                      2742
# abandono ecommerce movil      2360
# desborde ivr movil            1512
# abandono vtex                 1057
# discovery                      607
# leadgenios                     600
# bot                            113
# youtube                        109
# instagram                       95
# braze                           94
# arkero                          40
# tiktok                          26
# dv                              10
# convertia                        6
# desborde ivr home                5
# taptap                           4
# cmgroup home                     3
# app                              3
# pruebas                          3
# peoplemedia                      3
# extwebsite                       1
# pardot                           1
# el tiempo                        1
# Name: count, dtype: int64
#
# Medio_Pauta_2
# sem                        60.51930
# facebook                   17.15605
# abandono ecommerce home     7.23398
# masiv                       5.78247
# portal                      4.51999
# display                     2.02210
# walmeric                    0.80731
# abandono ecommerce movil    0.69484
# desborde ivr movil          0.44517
# abandono vtex               0.31121
# discovery                   0.17871
# leadgenios                  0.17665
# bot                         0.03327
# youtube                     0.03209
# instagram                   0.02797
# braze                       0.02768
# arkero                      0.01178
# tiktok                      0.00766
# dv                          0.00294
# convertia                   0.00177
# desborde ivr home           0.00147
# taptap                      0.00118
# cmgroup home                0.00088
# app                         0.00088
# pruebas                     0.00088
# peoplemedia                 0.00088
# extwebsite                  0.00029
# pardot                      0.00029
# el tiempo                   0.00029
# Name: proportion, dtype: float64

# %%
BD_funnel_consol['Medio_Pauta_pareto'] = np.where((BD_funnel_consol['Medio_Pauta_2'] =='sem') , 'sem',
                                              np.where((BD_funnel_consol['Medio_Pauta_2'] == 'facebook'), 'facebook',
                                                       np.where((BD_funnel_consol['Medio_Pauta_2'] == 'abandono ecommerce home'), 'abandono ecommerce home',
                                                                np.where((BD_funnel_consol['Medio_Pauta_2'] == 'masiv'), 'masiv',
                                                                         np.where((BD_funnel_consol['Medio_Pauta_2'] == 'portal'), 'portal','otro')))))

print(BD_funnel_consol['Medio_Pauta_pareto'].value_counts(dropna=False))
print()
print(BD_funnel_consol['Medio_Pauta_pareto'].value_counts(True,dropna=False)*100)
# Out:
# Medio_Pauta_pareto
# sem                        205552
# facebook                    58270
# abandono ecommerce home     24570
# masiv                       19640
# otro                        16263
# portal                      15352
# Name: count, dtype: int64
#
# Medio_Pauta_pareto
# sem                       60.51930
# facebook                  17.15605
# abandono ecommerce home    7.23398
# masiv                      5.78247
# otro                       4.78821
# portal                     4.51999
# Name: proportion, dtype: float64

# %% [markdown]
# #### Codigo de resultado

# %%
print(BD_funnel_consol['Codigo de resultado'].value_counts(dropna=False))
print()
print(BD_funnel_consol['Codigo de resultado'].value_counts(True,dropna=False)*100)
# Out:
# Codigo de resultado
# BLENDING MOVIL                                                       53521
# PETICIONES                                                           36765
# ININ-OUTBOUND-DISCONNECT                                             32775
# BLENDING HOME                                                        28224
# CUELGUE                                                              24936
# ININ-OUTBOUND-MACHINE                                                21867
# Answering Machine Detected                                           19434
# ININ-OUTBOUND-NUMBER_COULD_NOT_BE_DIALED                             17971
# General Error                                                         9588
# NO DILIGENCIO EL FORMULARIO                                           8782
# ESTADO DEL PEDIDO                                                     7695
# YA SE COMUNICARON  CON EL                                             7390
# Factura                                                               6804
# SOPORTE TECNICO                                                       6395
# LLAMADA EQUIVOCADA                                                    4694
# LLAMADA MUDA                                                          4345
# No Answer                                                             4310
# ININ-OUTBOUND-CAMPAIGN-RECYCLE-CANCELLED                              3942
# REQUIERE SOLO EQUIPO MOVIL                                            3629
# ININ-WRAP-UP-TIMEOUT                                                  3566
# FACTURA                                                               3287
# LLAMAR MAS TARDE                                                      3205
# ININ-OUTBOUND-NO-ANSWER                                               3032
# SIT Unknown Call State                                                2753
# MUNICIPIOS SIN COBERTURA                                              2524
# Busy                                                                  2453
# PETICION PREPAGO                                                      2401
# ININ-OUTBOUND-TRANSFERRED-TO-FLOW                                     2054
# ININ-OUTBOUND-BUSY                                                    1831
# ININ-OUTBOUND-SIT-UNCALLABLE                                          1432
# SIT Invalid Number                                                    1381
# CANAL WIN SPORTS PLUS                                                 1108
# CONTESTADORA AUTOMATICA                                                643
# Pymes                                                                  544
# PYMES                                                                  367
# CAMBIOS DE VELOCIDAD                                                   335
# DECIDE IR A UNA OFICINA                                                332
# Remote Release                                                         331
# ININ-OUTBOUND-AMBIGUOUS                                                294
# IVR                                                                    272
# CONTESTADORA AUTOMÁTICA                                                236
# ININ-OUTBOUND-ZONE-BLOCKED-SKIPPED                                     228
# Dropped                                                                204
# Contacto_Exitoso                                                       195
# NIÑOS                                                                  169
# NO_VENTA-NO_HAY_COBERTURA                                              168
# EDATEL                                                                 142
# Silence                                                                 92
# NaN                                                                     91
# VENTA VTEX                                                              89
# VENTA-TRIPLE                                                            66
# NO_VENTA-LO_PENSARA_O_CONSULTARA                                        65
# OTRAS_LLAMADAS-CUELGUE                                                  63
# Answer                                                                  57
# Abandoned                                                               50
# BARRIOS RESTRINGIDOS BELLO                                              44
# ININ-OUTBOUND-SIT-CALLABLE                                              40
# ININ-OUTBOUND-NUMBERS-INVALID                                           40
# NINOS                                                                   39
# NO_VENTA-TARIFA_ALTA                                                    28
# NO_VENTA-VENTA_FUTURA                                                   28
# VENTA-DUO                                                               23
# OTRAS_LLAMADAS-LLAMADA_MUDA                                             17
# ININ-OUTBOUND-PREVIEW-SKIPPED                                           17
# NO_VENTA-QUEDARA_A_NOMBRE_DE_OTRO                                       16
# NO_VENTA-NO_SE_AJUSTA_A_LAS_CARACTERISTICAS                             13
# CAMPANA AGENDAMIENTO                                                    13
# VENTA-INTERNET                                                          13
# NO_VENTA-NO_APROBADO_CARTERA                                            11
# MALA_TRANSFERENCIA-SERVICIO_AL_CLIENTE_TIGO                             11
# NO_VENTA-NO_CUENTA_CON_DIRECCION                                        11
# ININ-OUTBOUND-CONTACT-ATTEMPT-LIMIT-SKIP                                10
# MALA_TRANSFERENCIA-MUNICIPIO_SIN_COBERTURA                              10
# PEREIRA                                                                  9
# NO_VENTA-POR_POLITICA_ESPECIAL_DE_LA_REGIONAL                            9
# NO_VENTA-MEJOR_OFERTA_DE_OTRO_OPERADOR                                   7
# NO_VENTA-NO_PASA_EVIDENTE                                                7
# LLAMADA CORTADA                                                          6
# VENTA-PRE_A_POS                                                          6
# ININ-OUTBOUND-FAILED-TO-REACH-FLOW                                       6
# MALA_TRANSFERENCIA-VENTAS_DE_EDATEL_ETP                                  5
# SIT NC (No Circuit)                                                      5
# OTRAS_LLAMADAS-CUELGUE-SIN_SEÑAL_O_SIN_SALDO_O_SE_DESCARGO_EL_CEL        5
# MANIZALES                                                                5
# NUMERO_CONTACTO_INVALIDO_BI                                              4
# NO_VENTA-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA_CEDULA                       4
# MALA_TRANSFERENCIA-VENTAS_PYMES                                          4
# MALA_TRANSFERENCIA-SERVICIO_MOVIL                                        3
# OTRAS_LLAMADAS-PRUEBAS_IVR                                               3
# ININ-OUTBOUND-LIVE-VOICE                                                 3
# MALAS_TRANSFERENCIAS-ESTADO_DE_PEDIDO                                    3
# MALAS_TRANSFERENCIAS-SERVICIO_AL_CLIENTE_TIGO                            3
# VENTA-TRIPLE_+_MOVIL                                                     2
# NO_VENTA-RESTRICCION_GPON                                                2
# MALAS-TRANSFERENCIAS-SERVICIO-HOME                                       2
# Fax Detected                                                             2
# VENTA-INTERNET_+_MOVIL                                                   2
# VENTA-PAQUETES_PREMIUM                                                   2
# NO_VENTA-LO_TOMARA_POR_OFICINA_O_PAP                                     2
# NO_VENTA-PAGO_PARCIAL_DE_CONEXION                                        2
# NO_VENTA-PAGO_ANTICIPADO_CARGO_BASICO_PACB                               2
# MALA_TRANSFERENCIA-SAC                                                   2
# NO_VENTA-TIGO_MIGRACION-NO_APROBADO_CARTERA_TIGO                         2
# NO_VENTA-MOVISTAR-LO_PENSARA_O_CONSULTARA                                2
# VENTA-TELEVISION                                                         1
# NO_VENTA-TIGO_MIGRACION-NO_CUENTA_CON_DOCUMENTO_VALIDO                   1
# B2B_NO_EFECTIVO-N1-PETICIONES                                            1
# NO_VENTA-TIGO_MIGRACION-LO_PENSARA_O_CONSULTARA                          1
# NO_VENTA-RESTRICCION_REDCO                                               1
# MALAS_TRANSFERENCIAS-NO_COBERTURA                                        1
# VENTA-DUO_+_MOVIL                                                        1
# VENTA-LINEA_PORTADA                                                      1
# NO_VENTA-TIGO_MIGRACION-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA_CEDULA        1
# NO_VENTA-CONVERGENCIA_DIFERENTE_TITULAR                                  1
# NO_VENTA-TIGO_MIGRACION-TARIFA_ALTA                                      1
# ININ-OUTBOUND-CAMPAIGN-FORCED-OFF                                        1
# NO_VENTA-OTROS-NO_APROBADO_CARTERA_TIGO                                  1
# VENTA-MOVILIDAD-LINEA_NUEVA                                              1
# B2B_NO_EFECTIVO-N1-HOGAR                                                 1
# Name: count, dtype: int64
#
# Codigo de resultado
# BLENDING MOVIL                                                      15.75783
# PETICIONES                                                          10.82447
# ININ-OUTBOUND-DISCONNECT                                             9.64972
# BLENDING HOME                                                        8.30980
# CUELGUE                                                              7.34174
# ININ-OUTBOUND-MACHINE                                                6.43815
# Answering Machine Detected                                           5.72182
# ININ-OUTBOUND-NUMBER_COULD_NOT_BE_DIALED                             5.29108
# General Error                                                        2.82293
# NO DILIGENCIO EL FORMULARIO                                          2.58563
# ESTADO DEL PEDIDO                                                    2.26559
# YA SE COMUNICARON  CON EL                                            2.17579
# Factura                                                              2.00326
# SOPORTE TECNICO                                                      1.88284
# LLAMADA EQUIVOCADA                                                   1.38202
# LLAMADA MUDA                                                         1.27927
# No Answer                                                            1.26896
# ININ-OUTBOUND-CAMPAIGN-RECYCLE-CANCELLED                             1.16062
# REQUIERE SOLO EQUIPO MOVIL                                           1.06846
# ININ-WRAP-UP-TIMEOUT                                                 1.04991
# FACTURA                                                              0.96777
# LLAMAR MAS TARDE                                                     0.94363
# ININ-OUTBOUND-NO-ANSWER                                              0.89269
# SIT Unknown Call State                                               0.81055
# MUNICIPIOS SIN COBERTURA                                             0.74312
# Busy                                                                 0.72222
# PETICION PREPAGO                                                     0.70691
# ININ-OUTBOUND-TRANSFERRED-TO-FLOW                                    0.60475
# ININ-OUTBOUND-BUSY                                                   0.53909
# ININ-OUTBOUND-SIT-UNCALLABLE                                         0.42161
# SIT Invalid Number                                                   0.40660
# CANAL WIN SPORTS PLUS                                                0.32622
# CONTESTADORA AUTOMATICA                                              0.18931
# Pymes                                                                0.16017
# PYMES                                                                0.10805
# CAMBIOS DE VELOCIDAD                                                 0.09863
# DECIDE IR A UNA OFICINA                                              0.09775
# Remote Release                                                       0.09745
# ININ-OUTBOUND-AMBIGUOUS                                              0.08656
# IVR                                                                  0.08008
# CONTESTADORA AUTOMÁTICA                                              0.06948
# ININ-OUTBOUND-ZONE-BLOCKED-SKIPPED                                   0.06713
# Dropped                                                              0.06006
# Contacto_Exitoso                                                     0.05741
# NIÑOS                                                                0.04976
# NO_VENTA-NO_HAY_COBERTURA                                            0.04946
# EDATEL                                                               0.04181
# Silence                                                              0.02709
# NaN                                                                  0.02679
# VENTA VTEX                                                           0.02620
# VENTA-TRIPLE                                                         0.01943
# NO_VENTA-LO_PENSARA_O_CONSULTARA                                     0.01914
# OTRAS_LLAMADAS-CUELGUE                                               0.01855
# Answer                                                               0.01678
# Abandoned                                                            0.01472
# BARRIOS RESTRINGIDOS BELLO                                           0.01295
# ININ-OUTBOUND-SIT-CALLABLE                                           0.01178
# ININ-OUTBOUND-NUMBERS-INVALID                                        0.01178
# NINOS                                                                0.01148
# NO_VENTA-TARIFA_ALTA                                                 0.00824
# NO_VENTA-VENTA_FUTURA                                                0.00824
# VENTA-DUO                                                            0.00677
# OTRAS_LLAMADAS-LLAMADA_MUDA                                          0.00501
# ININ-OUTBOUND-PREVIEW-SKIPPED                                        0.00501
# NO_VENTA-QUEDARA_A_NOMBRE_DE_OTRO                                    0.00471
# NO_VENTA-NO_SE_AJUSTA_A_LAS_CARACTERISTICAS                          0.00383
# CAMPANA AGENDAMIENTO                                                 0.00383
# VENTA-INTERNET                                                       0.00383
# NO_VENTA-NO_APROBADO_CARTERA                                         0.00324
# MALA_TRANSFERENCIA-SERVICIO_AL_CLIENTE_TIGO                          0.00324
# NO_VENTA-NO_CUENTA_CON_DIRECCION                                     0.00324
# ININ-OUTBOUND-CONTACT-ATTEMPT-LIMIT-SKIP                             0.00294
# MALA_TRANSFERENCIA-MUNICIPIO_SIN_COBERTURA                           0.00294
# PEREIRA                                                              0.00265
# NO_VENTA-POR_POLITICA_ESPECIAL_DE_LA_REGIONAL                        0.00265
# NO_VENTA-MEJOR_OFERTA_DE_OTRO_OPERADOR                               0.00206
# NO_VENTA-NO_PASA_EVIDENTE                                            0.00206
# LLAMADA CORTADA                                                      0.00177
# VENTA-PRE_A_POS                                                      0.00177
# ININ-OUTBOUND-FAILED-TO-REACH-FLOW                                   0.00177
# MALA_TRANSFERENCIA-VENTAS_DE_EDATEL_ETP                              0.00147
# SIT NC (No Circuit)                                                  0.00147
# OTRAS_LLAMADAS-CUELGUE-SIN_SEÑAL_O_SIN_SALDO_O_SE_DESCARGO_EL_CEL    0.00147
# MANIZALES                                                            0.00147
# NUMERO_CONTACTO_INVALIDO_BI                                          0.00118
# NO_VENTA-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA_CEDULA                   0.00118
# MALA_TRANSFERENCIA-VENTAS_PYMES                                      0.00118
# MALA_TRANSFERENCIA-SERVICIO_MOVIL                                    0.00088
# OTRAS_LLAMADAS-PRUEBAS_IVR                                           0.00088
# ININ-OUTBOUND-LIVE-VOICE                                             0.00088
# MALAS_TRANSFERENCIAS-ESTADO_DE_PEDIDO                                0.00088
# MALAS_TRANSFERENCIAS-SERVICIO_AL_CLIENTE_TIGO                        0.00088
# VENTA-TRIPLE_+_MOVIL                                                 0.00059
# NO_VENTA-RESTRICCION_GPON                                            0.00059
# MALAS-TRANSFERENCIAS-SERVICIO-HOME                                   0.00059
# Fax Detected                                                         0.00059
# VENTA-INTERNET_+_MOVIL                                               0.00059
# VENTA-PAQUETES_PREMIUM                                               0.00059
# NO_VENTA-LO_TOMARA_POR_OFICINA_O_PAP                                 0.00059
# NO_VENTA-PAGO_PARCIAL_DE_CONEXION                                    0.00059
# NO_VENTA-PAGO_ANTICIPADO_CARGO_BASICO_PACB                           0.00059
# MALA_TRANSFERENCIA-SAC                                               0.00059
# NO_VENTA-TIGO_MIGRACION-NO_APROBADO_CARTERA_TIGO                     0.00059
# NO_VENTA-MOVISTAR-LO_PENSARA_O_CONSULTARA                            0.00059
# VENTA-TELEVISION                                                     0.00029
# NO_VENTA-TIGO_MIGRACION-NO_CUENTA_CON_DOCUMENTO_VALIDO               0.00029
# B2B_NO_EFECTIVO-N1-PETICIONES                                        0.00029
# NO_VENTA-TIGO_MIGRACION-LO_PENSARA_O_CONSULTARA                      0.00029
# NO_VENTA-RESTRICCION_REDCO                                           0.00029
# MALAS_TRANSFERENCIAS-NO_COBERTURA                                    0.00029
# VENTA-DUO_+_MOVIL                                                    0.00029
# VENTA-LINEA_PORTADA                                                  0.00029
# NO_VENTA-TIGO_MIGRACION-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA_CEDULA    0.00029
# NO_VENTA-CONVERGENCIA_DIFERENTE_TITULAR                              0.00029
# NO_VENTA-TIGO_MIGRACION-TARIFA_ALTA                                  0.00029
# ININ-OUTBOUND-CAMPAIGN-FORCED-OFF                                    0.00029
# NO_VENTA-OTROS-NO_APROBADO_CARTERA_TIGO                              0.00029
# VENTA-MOVILIDAD-LINEA_NUEVA                                          0.00029
# B2B_NO_EFECTIVO-N1-HOGAR                                             0.00029
# Name: proportion, dtype: float64

# %%
print(BD_funnel_consol['Gerencia'].value_counts(dropna=False))
print()
print(BD_funnel_consol['Gerencia'].value_counts(True,dropna=False)*100)
# Out:
# Gerencia
# Digital           319782
# Medios Propios     19865
# Name: count, dtype: int64
#
# Gerencia
# Digital          94.15128
# Medios Propios    5.84872
# Name: proportion, dtype: float64

# %%
BD_funnel_consol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 339647 entries, 0 to 339646
# Data columns (total 39 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   CALLID                339647 non-null  object
#  1   Telefono              339646 non-null  object
#  2   Nombre usuario        330876 non-null  object
#  3   Id Oferta             337348 non-null  object
#  4   Descripcion Oferta    253152 non-null  object
#  5   Descripcion Opcional  320286 non-null  object
#  6   Codigo de resultado   339556 non-null  object
#  7   Fecha efectiva        339556 non-null  object
#  8   Hora efectiva         339556 non-null  object
#  9   Duracion              338761 non-null  float64
#  10  Asesor                213987 non-null  object
#  11  Jobname               339556 non-null  object
#  12  Correo                73066 non-null   object
#  13  DescSolicitudCliente  256886 non-null  object
#  14  Fecha primer intento  339548 non-null  object
#  15  Hora primer intento   339548 non-null  object
#  16  Gerencia              339647 non-null  object
#  17  Negocio               339647 non-null  object
#  18  Medio Pauta           339647 non-null  object
#  19  fecha_registro_2      339647 non-null  datetime64[ns]
#  20  anio_mes              339647 non-null  object
#  21  ANI                   54190 non-null   float64
#  22  Asesor_call           52946 non-null   object
#  23  Duracion_Seg          54190 non-null   float64
#  24  Piloto                54190 non-null   object
#  25  Nivel1                50534 non-null   object
#  26  Nivel2                50520 non-null   object
#  27  Nivel3                14874 non-null   object
#  28  Nivel4                0 non-null       float64
#  29  CodFinalizacion       54190 non-null   object
#  30  Estado                54190 non-null   object
#  31  DNIS                  54190 non-null   object
#  32  Negocio_call          54190 non-null   object
#  33  Linea                 0 non-null       object
#  34  BU                    0 non-null       object
#  35  Gerencia_call         0 non-null       object
#  36  Origen                54190 non-null   object
#  37  fecha_2               54190 non-null   datetime64[ns]
#  38  anio_mes_2            54190 non-null   object
# dtypes: datetime64[ns](2), float64(4), object(33)
# memory usage: 101.1+ MB

# %% [markdown]
# ### 2.2 Análisis EDA

# %% [markdown]
# Tenga en cuenta los siguientes conceptos:
# -	Calidad: Relación entre los registros con intención de compra en primera instancia y la cantidad total de registros
# -	Efectividad: Relación entre las ventas cerradas y los registros con intención de compra en primera instancia
# -	Calificados: Registros con intención de compra en primera instancia
# -	Contacto efectivo: Registro en el que se logró tener una conversación con el cliente
# -	Contacto más efectivo: Los resultados de la llamada se priorizan, si bien no siempre se logra tener contacto con el cliente, algunos códigos de resultado son más efectivos que otros, por ejemplo: Un buzón de voz es más efectivo es más efectivo que un tono muerto

# %% [markdown]
# Calidad

# %%
BD_funnel_consol.dtypes
# Out:
# CALLID                          object
# Telefono                        object
# Nombre usuario                  object
# Id Oferta                       object
# Descripcion Oferta              object
# Descripcion Opcional            object
# Codigo de resultado             object
# Fecha efectiva                  object
# Hora efectiva                   object
# Duracion                       float64
# Asesor                          object
# Jobname                         object
# Correo                          object
# DescSolicitudCliente            object
# Fecha primer intento            object
# Hora primer intento             object
# Gerencia                        object
# Negocio                         object
# Medio Pauta                     object
# fecha_registro_2        datetime64[ns]
# anio_mes                        object
# ANI                            float64
# Asesor_call                     object
# Duracion_Seg                   float64
# Piloto                          object
# Nivel1                          object
# Nivel2                          object
# Nivel3                          object
# Nivel4                         float64
# CodFinalizacion                 object
# Estado                          object
# DNIS                            object
# Negocio_call                    object
# Linea                           object
# BU                              object
# Gerencia_call                   object
# Origen                          object
# fecha_2                 datetime64[ns]
# anio_mes_2                      object
# Medio_Pauta_2                   object
# Medio_Pauta_pareto              object
# dtype: object

# %%
print(BD_funnel_consol['Nivel1'].value_counts(dropna=False))
print()
print(BD_funnel_consol['Nivel1'].value_counts(True,dropna=False)*100)
# Out:
# Nivel1
# NaN                                       289113
# NO VENTA                                   20159
# VENTA                                      19112
# OTRAS LLAMADAS                              7809
# MALAS TRANSFERENCIAS                         930
# NO_VENTA                                     901
# MALA_TRANSFERENCIA                           695
# MALA TRANSFERENCIA                           659
# MALAS_TRANSFERENCIAS                         255
# TENTATIVA DE FRAUDE SE ENVIA A OFICINA        14
# Name: count, dtype: int64
#
# Nivel1
# NaN                                      85.12161
# NO VENTA                                  5.93528
# VENTA                                     5.62702
# OTRAS LLAMADAS                            2.29915
# MALAS TRANSFERENCIAS                      0.27381
# NO_VENTA                                  0.26528
# MALA_TRANSFERENCIA                        0.20462
# MALA TRANSFERENCIA                        0.19402
# MALAS_TRANSFERENCIAS                      0.07508
# TENTATIVA DE FRAUDE SE ENVIA A OFICINA    0.00412
# Name: proportion, dtype: float64

# %%
print(BD_funnel_consol['CodFinalizacion'].value_counts(dropna=False))
print()
print(BD_funnel_consol['CodFinalizacion'].value_counts(True,dropna=False)*100)
# Out:
# CodFinalizacion
# NaN                                                                285457
# VENTA-Linea_Portada                                                  7359
# VENTA-PRE_A_POS                                                      6421
# NO_VENTA-NO_HAY_COBERTURA                                            5196
# OTRAS_LLAMADAS-CUELGUE-SIN_SEÑAL_O_SIN_SALDO_O_SE_                   3905
# VENTA-TRIPLE                                                         3022
# No Asignado                                                          2412
# NO_VENTA-LO_PENSARA_O_CONSULTARA                                     2127
# OTRAS_LLAMADAS-CUELGUE                                               1703
# Abandonada                                                           1244
# NO_VENTA-TIGO_MIGRACION-NO_APROBADO_CARTERA_TIGO                     1201
# NO_VENTA-VENTA_FUTURA                                                1052
# NO_VENTA-CLARO-LO_PENSARA_O_CONSULTARA                                781
# OTRAS_LLAMADAS-LLAMADA_MUDA                                           739
# VENTA-DUO                                                             730
# OTRAS_LLAMADAS-CUELGUE-ENTRA_LLAMADA_Y_SE_CUELGA_S                    684
# MALAS_TRANSFERENCIAS-SERVICIO_AL_CLIENTE_TIGO                         633
# NO_VENTA-TARIFA_ALTA                                                  612
# NO_VENTA-NO_SE_AJUSTA_A_LAS_CARACTERISTICAS                           605
# NO_VENTA-MOVISTAR-LO_PENSARA_O_CONSULTARA                             569
# OTRAS_LLAMADAS-CUELGUE-SOLO_DESEA_COTIZAR                             558
# NO_VENTA-NO_CUENTA_CON_DIRECCION                                      532
# NO_VENTA-NO_APROBADO_CARTERA                                          515
# NO_VENTA-TIGO_MIGRACION-LO_PENSARA_O_CONSULTARA                       444
# NO_VENTA-CLARO-NO_APROBADO_CARTERA_TIGO                               434
# NO_VENTA-TIGO_MIGRACION-NO_CUENTA_CON_DOCUMENTO_VA                    432
# VENTA-INTERNET                                                        410
# NO_VENTA-NO_PASA_EVIDENTE                                             404
# NO_VENTA-OTROS-LO_PENSARA_O_CONSULTARA                                398
# NO_VENTA-MOVISTAR-NO_APROBADO_CARTERA_TIGO                            363
# VENTA-PAQUETES_PREMIUM                                                356
# MALA_TRANSFERENCIA-SERVICIO_AL_CLIENTE_TIGO                           336
# NO_VENTA-QUEDARA_A_NOMBRE_DE_OTRO                                     327
# VENTA_CEDULA_VERIFICADA_MOVIL                                         311
# MALA_TRANSFERENCIA-VENTAS_DE_EDATEL_ETP                               298
# NO_VENTA-CLARO-NO_CUENTA_CON_DIRECCION                                291
# MALA_TRANSFERENCIA-SAC                                                273
# MALAS_TRANSFERENCIAS-Estado_de_pedido                                 255
# NO_VENTA-CLARO-DESEA_OFERTA_NO_DISPONIBLE                             219
# MALA_TRANSFERENCIA-MUNICIPIO_SIN_COBERTURA                            208
# NO_VENTA-OTROS-NO_APROBADO_CARTERA_TIGO                               184
# NO_VENTA-MOVISTAR-DESEA_OFERTA_NO_DISPONIBLE                          161
# NO_VENTA-MOVISTAR-NO_CUENTA_CON_SIM_ACTIVA_PARA_PO                    160
# NO_VENTA-CLARO-NO_CUENTA_CON_SIM_ACTIVA_PARA_PORTA                    160
# NO_VENTA-CLARO-DECIDE_ACERCARSE_MEJOR_A_UNA_OFICIN                    151
# NO_VENTA-MEJOR_OFERTA_DE_OTRO_OPERADOR                                147
# NO_VENTA-TIGO_MIGRACION-DESEA_OFERTA_NO_DISPONIBLE                    146
# VENTA-TRIPLE_+_MOVIL                                                  145
# NO_VENTA-CLARO-CONVERGENCIA_DIFERENTE_TITULAR                         140
# MALA_TRANSFERENCIA-VENTAS_PYMES                                       140
# NO_VENTA-WOM-NO_APROBADO_CARTERA_TIGO                                 139
# NO_VENTA-MOVISTAR-TARIFA_ALTA                                         136
# NO_VENTA-OTROS-DESEA_OFERTA_NO_DISPONIBLE                             134
# NO_VENTA-CLARO-TARIFA_ALTA                                            131
# NO_VENTA-TIGO_MIGRACION-NO_TIENE_FECHA_DE_EXPEDICI                    127
# NO_VENTA-MOVISTAR-NO_CUENTA_CON_DIRECCION                             121
# NO_VENTA-TIGO_MIGRACION-NO_CUENTA_CON_SIM_ACTIVA_P                    116
# OTRAS_LLAMADAS-CUELGUE-CUELGA_AL_ESCUCHAR_RECAUDO                     110
# NO_VENTA-OTROS-QUEDARA_A_NOMBRE_DE_OTRO                               105
# NO_VENTA-CLARO-QUEDARA_A_NOMBRE_DE_OTRO                               102
# VENTA-MOVILIDAD-LINEA_NUEVA                                           101
# NO_VENTA-WOM-LO_PENSARA_O_CONSULTARA                                  100
# MALAS_TRANSFERENCIAS-NO_COBERTURA                                      98
# NO_VENTA-POR_POLITICA_ESPECIAL_DE_LA_REGIONAL                          98
# MALAS_TRANSFERENCIAS-SOLO_REQUIERE_EQUIPO                              96
# MALAS-TRANSFERENCIAS-SERVICIO-HOME                                     92
# MALA_TRANSFERENCIA-SERVICIO_MOVIL                                      86
# NO_VENTA-MOVISTAR-DECIDE_ACERCARSE_MEJOR_A_UNA_OFI                     85
# NO_VENTA-MOVISTAR-QUEDARA_A_NOMBRE_DE_OTRO                             82
# NO_VENTA-PAGO_PARCIAL_DE_CONEXION                                      77
# NO_VENTA-TIGO_MIGRACION-NO_PASA_POLITICAS_FREE                         74
# NO_VENTA-CONVERGENCIA_DIFERENTE_TITULAR                                73
# NO_VENTA-OTROS-NO_CUENTA_CON_DOCUMENTO_VALIDO                          71
# NO_VENTA-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA_CEDULA                     70
# OTRAS_LLAMADAS-CUELGUE-NO_PASA_ESTUDIOS_O_SE_IDENT                     69
# NO_VENTA-CLARO-NO_CUENTA_CON_DOCUMENTO_VALIDO                          67
# VENTA-LINEA NUEVA                                                      62
# NO_VENTA-CLARO-MEJOR_OFERTA                                            60
# NO_VENTA-OTROS-DECIDE_ACERCARSE_MEJOR_A_UNA_OFICIN                     58
# NO_VENTA-OTROS-NO_CUENTA_CON_SIM_ACTIVA_PARA_PORTA                     55
# NO_VENTA-LO_TOMARA_POR_OFICINA_O_PAP                                   55
# VENTA-TELEVISION                                                       54
# NO_VENTA-CLARO-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA_                     54
# NO_VENTA-TIGO_MIGRACION-TARIFA_ALTA                                    52
# NO_VENTA-MOVISTAR-MEJOR_OFERTA                                         47
# NO_VENTA-OTROS-NO_CUENTA_CON_DIRECCION                                 47
# NO_VENTA-MOVISTAR-CONVERGENCIA_DIFERENTE_TITULAR                       44
# NO_VENTA-WOM-TARIFA_ALTA                                               43
# NO_VENTA-WOM-NO_CUENTA_CON_DIRECCION                                   41
# NO_VENTA-TIGO_MIGRACION-CONVERGENCIA_DIFERENTE_TIT                     41
# NO_VENTA-OTROS-TARIFA_ALTA                                             39
# NO_VENTA-MOVISTAR-NO_CUENTA_CON_DOCUMENTO_VALIDO                       38
# PYMES_UNE_VTAS-NO_VENTA-LO_PENSARA_O_CONSULTARA                        38
# NO_VENTA-OTROS-CONVERGENCIA_DIFERENTE_TITULAR                          38
# NO_VENTA-TIGO_MIGRACION-DECIDE_ACERCARSE_MEJOR_A_U                     36
# NO_VENTA-RESTRICCION_GPON                                              36
# NO_VENTA-PAGO_ANTICIPADO_CARGO_BASICO_PACB                             35
# VENTA-INTERNET_+_MOVIL                                                 31
# OTRAS_LLAMADAS-PREGUNTA_POR_ASESOR_ESPECIFICO                          29
# NO_VENTA-WOM-DESEA_OFERTA_NO_DISPONIBLE                                29
# PYMES_UNE_VTAS-NO_VENTA-INFORMACION_INCOMPLETA                         28
# NO_VENTA-WOM-NO_CUENTA_CON_SIM_ACTIVA_PARA_PORTAR                      27
# VENTA-DUO_+_MOVIL                                                      27
# NO_VENTA-OTROS-MEJOR_OFERTA                                            24
# NO_VENTA-MOVISTAR-NO_TIENE_FECHA_DE_EXPEDICION_DE_                     23
# VENTA_NIT_HOGAR                                                        23
# NO_VENTA-TIGO_MIGRACION-NO_CUENTA_CON_EL_PRIMER_CB                     22
# VENTA_CEDULA_VERIFICADA_HOGAR                                          21
# NO_VENTA-RESTRICCION_REDCO                                             21
# NO_VENTA-TIGO_MIGRACION-MEJOR_OFERTA                                   21
# NO_VENTA-VIRGIN-LO_PENSARA_O_CONSULTARA                                20
# NO_VENTA-WOM-QUEDARA_A_NOMBRE_DE_OTRO                                  19
# PYMES_NO_VENTA_TIGO_SOLICITA_LINEA_PREPAGO                             19
# PYMES_NO_VENTA_TIGO_INFORMACION_INCOMPLETA                             18
# VENTA_CONVEREGENCIA                                                    18
# PYMES_UNE_VTAS-NO_VENTA-OFERTA_NO_DISPONIBLE_PARA_NUESTRO_CANAL        16
# NO_VENTA-WOM-NO_CUENTA_CON_DOCUMENTO_VALIDO                            16
# VENTA_NIT_MOVIL                                                        16
# NO_VENTA-OTROS-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA_                     15
# TENTATIVA_DE_FRAUDE_SE_ENVIA_A_OFICINA                                 14
# NO_VENTA-WOM-DECIDE_ACERCARSE_MEJOR_A_UNA_OFICINA                      14
# PYMES_UNE_VTAS-NO_VENTA-NO_HAY_COBERTURA                               14
# VTAS-NO_VENTA_TRANSFERENCIA_PYMES                                      13
# OTRAS_LLAMADAS-PRUEBAS_IVR                                             12
# MALAS_TRANSFERENCIAS-VENTAS_B2B                                        11
# NO_VENTA-WOM-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA_CE                     11
# NO_VENTA-WOM-CONVERGENCIA_DIFERENTE_TITULAR                            11
# NO_VENTA-VIRGIN-NO_APROBADO_CARTERA_TIGO                               10
# NO_VENTA-TIGO_MIGRACION-NO_CUENTA_CON_DIRECCION                        10
# PYMES_UNE_VTAS-NO_VENTA-VENTA_FUTURA                                    9
# NO_VENTA-AVANTEL-LO_PENSARA_O_CONSULTARA                                8
# NO_VENTA-WOM-MEJOR_OFERTA                                               8
# NO_VENTA-VIRGIN-DECIDE_ACERCARSE_MEJOR_A_UNA_OFICI                      7
# NO_VENTA-VIRGIN-DESEA_OFERTA_NO_DISPONIBLE                              7
# NO_VENTA-VIRGIN-NO_CUENTA_CON_SIM_ACTIVA_PARA_PORT                      7
# PYMES_UNE_VTAS-NO_VENTA-NO_APROBADO_CARTERA                             7
# PYMES_UNE_VTAS-NO_VENTA-TARIFA_ALTA                                     6
# NO_VENTA-VIRGIN-CONVERGENCIA_DIFERENTE_TITULAR                          6
# PYMES_UNE_VTAS-NO_VENTA-LO_TOMARA_POR_OFICINA_O_PAP                     6
# PYMES_UNE_VTAS-NO_VENTA-QUEDARA_A_NOMBRE_DE_OTRO                        5
# NO_VENTA-AVANTEL-NO_APROBADO_CARTERA_TIGO                               5
# NO_VENTA-VIRGIN-NO_CUENTA_CON_DOCUMENTO_VALIDO                          5
# NO_VENTA-VIRGIN-TARIFA_ALTA                                             4
# PYMES_UNE_VTAS-NO_VENTA-NO_PASA_EVIDENTE                                4
# PYMES_UNE_VTAS-NO_VENTA-NO_SE_AJUSTA_A_LAS_CARACTERISTICAS              3
# VENTA-TELEVISION_+_MOVIL                                                3
# PYMES_NO_VENTA_TIGO_SOLICITA_PROMO_SMS                                  3
# NO_VENTA-VIRGIN-NO_CUENTA_CON_DIRECCION                                 3
# PYMES_NO_VENTA_TIGO_CLIENTE_DESEA_OFERTA_NO_DISPON                      3
# PYMES_NO_VENTA_TIGO_NO_CUENTA_CON_DOCUMENTO_VALIDO                      3
# PYMES_NO_VENTA_TIGO_DESEA_PLAN_DE_SOLO_DATOS_O_MIN                      3
# NO_VENTA-VIRGIN-QUEDARA_A_NOMBRE_DE_OTRO                                3
# PYMES_UNE_VTAS-NO_VENTA-MEJOR_OFERTA                                    2
# PYMES_UNE_VTAS-NO_VENTA-PAGO_PARCIAL_DE_CONEXION                        2
# PYMES_NO_VENTA_TIGO_NO_CUENTA_CON_SIM_ACTIVA_PARA_                      2
# PYMES_NO_VENTA_TIGO_LO_PENSARA_O_CONSULTARA                             2
# NO_VENTA-VIRGIN-MEJOR_OFERTA                                            2
# NO_VENTA-NO_CUMPLE_PRIMERA_FACTURA_EXISTENTE                            2
# PYMES_NO_VENTA_TIGO_USUARIO_NO_CUENTA_CON_EL_PRIME                      2
# PYMES_UNE_VTAS-NO_VENTA-RESTRICCION_REDCO                               2
# PYMES_NO_VENTA_TIGO_SALDOS_PENDIENTES_EN_HOME                           2
# VENTA-TELEFONIA                                                         2
# NO_VENTA-AVANTEL-DESEA_OFERTA_NO_DISPONIBLE                             2
# PYMES_UNE_VTAS-NO_VENTA-CLIENTE_SIN_NIP                                 2
# NO_VENTA-AVANTEL-DECIDE_ACERCARSE_MEJOR_A_UNA_OFIC                      2
# PYMES_NO_VENTA_TIGO_FECHA_DE_EXPEDICION_DE_LA_CEDU                      2
# PYMES_NO_VENTA_TIGO_NO_APROBADO_CARTERA                                 2
# PYMES_NO_VENTA_TIGO_CONVERGENCIA_DIFERENTE_TITULAR                      1
# NO_VENTA-AVANTEL-CONVERGENCIA_DIFERENTE_TITULAR                         1
# PYMES_NO_VENTA_TIGO_MEJOR_OFERTA                                        1
# PYMES_NO_VENTA_TIGO_DECIDE_ACERCARSE_MEJOR_A_UNA_O                      1
# NO_VENTA-VIRGIN-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA                      1
# NO_VENTA-AVANTEL-MEJOR_OFERTA                                           1
# PYMES_UNE_VTAS-NO_VENTA-INCONFORME_CON_CONTENIDO                        1
# NO_VENTA-CLARO-ZONA_ROJA                                                1
# NO_VENTA-AVANTEL-QUEDARA_A_NOMBRE_DE_OTRO                               1
# PYMES_NO_VENTA_TIGO_TARIFA_ALTA                                         1
# NO_VENTA-OTROS-ZONA_ROJA                                                1
# PYMES_UNE_VTAS-NO_VENTA-PAGO_ANTICIPADO_CARGO_BASICO_PACB               1
# NO_VENTA-MOVISTAR-ZONA_ROJA                                             1
# Name: count, dtype: int64
#
# CodFinalizacion
# NaN                                                               84.04520
# VENTA-Linea_Portada                                                2.16666
# VENTA-PRE_A_POS                                                    1.89049
# NO_VENTA-NO_HAY_COBERTURA                                          1.52982
# OTRAS_LLAMADAS-CUELGUE-SIN_SEÑAL_O_SIN_SALDO_O_SE_                 1.14972
# VENTA-TRIPLE                                                       0.88975
# No Asignado                                                        0.71015
# NO_VENTA-LO_PENSARA_O_CONSULTARA                                   0.62624
# OTRAS_LLAMADAS-CUELGUE                                             0.50140
# Abandonada                                                         0.36626
# NO_VENTA-TIGO_MIGRACION-NO_APROBADO_CARTERA_TIGO                   0.35360
# NO_VENTA-VENTA_FUTURA                                              0.30973
# NO_VENTA-CLARO-LO_PENSARA_O_CONSULTARA                             0.22994
# OTRAS_LLAMADAS-LLAMADA_MUDA                                        0.21758
# VENTA-DUO                                                          0.21493
# OTRAS_LLAMADAS-CUELGUE-ENTRA_LLAMADA_Y_SE_CUELGA_S                 0.20139
# MALAS_TRANSFERENCIAS-SERVICIO_AL_CLIENTE_TIGO                      0.18637
# NO_VENTA-TARIFA_ALTA                                               0.18019
# NO_VENTA-NO_SE_AJUSTA_A_LAS_CARACTERISTICAS                        0.17813
# NO_VENTA-MOVISTAR-LO_PENSARA_O_CONSULTARA                          0.16753
# OTRAS_LLAMADAS-CUELGUE-SOLO_DESEA_COTIZAR                          0.16429
# NO_VENTA-NO_CUENTA_CON_DIRECCION                                   0.15663
# NO_VENTA-NO_APROBADO_CARTERA                                       0.15163
# NO_VENTA-TIGO_MIGRACION-LO_PENSARA_O_CONSULTARA                    0.13072
# NO_VENTA-CLARO-NO_APROBADO_CARTERA_TIGO                            0.12778
# NO_VENTA-TIGO_MIGRACION-NO_CUENTA_CON_DOCUMENTO_VA                 0.12719
# VENTA-INTERNET                                                     0.12071
# NO_VENTA-NO_PASA_EVIDENTE                                          0.11895
# NO_VENTA-OTROS-LO_PENSARA_O_CONSULTARA                             0.11718
# NO_VENTA-MOVISTAR-NO_APROBADO_CARTERA_TIGO                         0.10688
# VENTA-PAQUETES_PREMIUM                                             0.10481
# MALA_TRANSFERENCIA-SERVICIO_AL_CLIENTE_TIGO                        0.09893
# NO_VENTA-QUEDARA_A_NOMBRE_DE_OTRO                                  0.09628
# VENTA_CEDULA_VERIFICADA_MOVIL                                      0.09157
# MALA_TRANSFERENCIA-VENTAS_DE_EDATEL_ETP                            0.08774
# NO_VENTA-CLARO-NO_CUENTA_CON_DIRECCION                             0.08568
# MALA_TRANSFERENCIA-SAC                                             0.08038
# MALAS_TRANSFERENCIAS-Estado_de_pedido                              0.07508
# NO_VENTA-CLARO-DESEA_OFERTA_NO_DISPONIBLE                          0.06448
# MALA_TRANSFERENCIA-MUNICIPIO_SIN_COBERTURA                         0.06124
# NO_VENTA-OTROS-NO_APROBADO_CARTERA_TIGO                            0.05417
# NO_VENTA-MOVISTAR-DESEA_OFERTA_NO_DISPONIBLE                       0.04740
# NO_VENTA-MOVISTAR-NO_CUENTA_CON_SIM_ACTIVA_PARA_PO                 0.04711
# NO_VENTA-CLARO-NO_CUENTA_CON_SIM_ACTIVA_PARA_PORTA                 0.04711
# NO_VENTA-CLARO-DECIDE_ACERCARSE_MEJOR_A_UNA_OFICIN                 0.04446
# NO_VENTA-MEJOR_OFERTA_DE_OTRO_OPERADOR                             0.04328
# NO_VENTA-TIGO_MIGRACION-DESEA_OFERTA_NO_DISPONIBLE                 0.04299
# VENTA-TRIPLE_+_MOVIL                                               0.04269
# NO_VENTA-CLARO-CONVERGENCIA_DIFERENTE_TITULAR                      0.04122
# MALA_TRANSFERENCIA-VENTAS_PYMES                                    0.04122
# NO_VENTA-WOM-NO_APROBADO_CARTERA_TIGO                              0.04092
# NO_VENTA-MOVISTAR-TARIFA_ALTA                                      0.04004
# NO_VENTA-OTROS-DESEA_OFERTA_NO_DISPONIBLE                          0.03945
# NO_VENTA-CLARO-TARIFA_ALTA                                         0.03857
# NO_VENTA-TIGO_MIGRACION-NO_TIENE_FECHA_DE_EXPEDICI                 0.03739
# NO_VENTA-MOVISTAR-NO_CUENTA_CON_DIRECCION                          0.03563
# NO_VENTA-TIGO_MIGRACION-NO_CUENTA_CON_SIM_ACTIVA_P                 0.03415
# OTRAS_LLAMADAS-CUELGUE-CUELGA_AL_ESCUCHAR_RECAUDO                  0.03239
# NO_VENTA-OTROS-QUEDARA_A_NOMBRE_DE_OTRO                            0.03091
# NO_VENTA-CLARO-QUEDARA_A_NOMBRE_DE_OTRO                            0.03003
# VENTA-MOVILIDAD-LINEA_NUEVA                                        0.02974
# NO_VENTA-WOM-LO_PENSARA_O_CONSULTARA                               0.02944
# MALAS_TRANSFERENCIAS-NO_COBERTURA                                  0.02885
# NO_VENTA-POR_POLITICA_ESPECIAL_DE_LA_REGIONAL                      0.02885
# MALAS_TRANSFERENCIAS-SOLO_REQUIERE_EQUIPO                          0.02826
# MALAS-TRANSFERENCIAS-SERVICIO-HOME                                 0.02709
# MALA_TRANSFERENCIA-SERVICIO_MOVIL                                  0.02532
# NO_VENTA-MOVISTAR-DECIDE_ACERCARSE_MEJOR_A_UNA_OFI                 0.02503
# NO_VENTA-MOVISTAR-QUEDARA_A_NOMBRE_DE_OTRO                         0.02414
# NO_VENTA-PAGO_PARCIAL_DE_CONEXION                                  0.02267
# NO_VENTA-TIGO_MIGRACION-NO_PASA_POLITICAS_FREE                     0.02179
# NO_VENTA-CONVERGENCIA_DIFERENTE_TITULAR                            0.02149
# NO_VENTA-OTROS-NO_CUENTA_CON_DOCUMENTO_VALIDO                      0.02090
# NO_VENTA-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA_CEDULA                 0.02061
# OTRAS_LLAMADAS-CUELGUE-NO_PASA_ESTUDIOS_O_SE_IDENT                 0.02032
# NO_VENTA-CLARO-NO_CUENTA_CON_DOCUMENTO_VALIDO                      0.01973
# VENTA-LINEA NUEVA                                                  0.01825
# NO_VENTA-CLARO-MEJOR_OFERTA                                        0.01767
# NO_VENTA-OTROS-DECIDE_ACERCARSE_MEJOR_A_UNA_OFICIN                 0.01708
# NO_VENTA-OTROS-NO_CUENTA_CON_SIM_ACTIVA_PARA_PORTA                 0.01619
# NO_VENTA-LO_TOMARA_POR_OFICINA_O_PAP                               0.01619
# VENTA-TELEVISION                                                   0.01590
# NO_VENTA-CLARO-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA_                 0.01590
# NO_VENTA-TIGO_MIGRACION-TARIFA_ALTA                                0.01531
# NO_VENTA-MOVISTAR-MEJOR_OFERTA                                     0.01384
# NO_VENTA-OTROS-NO_CUENTA_CON_DIRECCION                             0.01384
# NO_VENTA-MOVISTAR-CONVERGENCIA_DIFERENTE_TITULAR                   0.01295
# NO_VENTA-WOM-TARIFA_ALTA                                           0.01266
# NO_VENTA-WOM-NO_CUENTA_CON_DIRECCION                               0.01207
# NO_VENTA-TIGO_MIGRACION-CONVERGENCIA_DIFERENTE_TIT                 0.01207
# NO_VENTA-OTROS-TARIFA_ALTA                                         0.01148
# NO_VENTA-MOVISTAR-NO_CUENTA_CON_DOCUMENTO_VALIDO                   0.01119
# PYMES_UNE_VTAS-NO_VENTA-LO_PENSARA_O_CONSULTARA                    0.01119
# NO_VENTA-OTROS-CONVERGENCIA_DIFERENTE_TITULAR                      0.01119
# NO_VENTA-TIGO_MIGRACION-DECIDE_ACERCARSE_MEJOR_A_U                 0.01060
# NO_VENTA-RESTRICCION_GPON                                          0.01060
# NO_VENTA-PAGO_ANTICIPADO_CARGO_BASICO_PACB                         0.01030
# VENTA-INTERNET_+_MOVIL                                             0.00913
# OTRAS_LLAMADAS-PREGUNTA_POR_ASESOR_ESPECIFICO                      0.00854
# NO_VENTA-WOM-DESEA_OFERTA_NO_DISPONIBLE                            0.00854
# PYMES_UNE_VTAS-NO_VENTA-INFORMACION_INCOMPLETA                     0.00824
# NO_VENTA-WOM-NO_CUENTA_CON_SIM_ACTIVA_PARA_PORTAR                  0.00795
# VENTA-DUO_+_MOVIL                                                  0.00795
# NO_VENTA-OTROS-MEJOR_OFERTA                                        0.00707
# NO_VENTA-MOVISTAR-NO_TIENE_FECHA_DE_EXPEDICION_DE_                 0.00677
# VENTA_NIT_HOGAR                                                    0.00677
# NO_VENTA-TIGO_MIGRACION-NO_CUENTA_CON_EL_PRIMER_CB                 0.00648
# VENTA_CEDULA_VERIFICADA_HOGAR                                      0.00618
# NO_VENTA-RESTRICCION_REDCO                                         0.00618
# NO_VENTA-TIGO_MIGRACION-MEJOR_OFERTA                               0.00618
# NO_VENTA-VIRGIN-LO_PENSARA_O_CONSULTARA                            0.00589
# NO_VENTA-WOM-QUEDARA_A_NOMBRE_DE_OTRO                              0.00559
# PYMES_NO_VENTA_TIGO_SOLICITA_LINEA_PREPAGO                         0.00559
# PYMES_NO_VENTA_TIGO_INFORMACION_INCOMPLETA                         0.00530
# VENTA_CONVEREGENCIA                                                0.00530
# PYMES_UNE_VTAS-NO_VENTA-OFERTA_NO_DISPONIBLE_PARA_NUESTRO_CANAL    0.00471
# NO_VENTA-WOM-NO_CUENTA_CON_DOCUMENTO_VALIDO                        0.00471
# VENTA_NIT_MOVIL                                                    0.00471
# NO_VENTA-OTROS-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA_                 0.00442
# TENTATIVA_DE_FRAUDE_SE_ENVIA_A_OFICINA                             0.00412
# NO_VENTA-WOM-DECIDE_ACERCARSE_MEJOR_A_UNA_OFICINA                  0.00412
# PYMES_UNE_VTAS-NO_VENTA-NO_HAY_COBERTURA                           0.00412
# VTAS-NO_VENTA_TRANSFERENCIA_PYMES                                  0.00383
# OTRAS_LLAMADAS-PRUEBAS_IVR                                         0.00353
# MALAS_TRANSFERENCIAS-VENTAS_B2B                                    0.00324
# NO_VENTA-WOM-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA_CE                 0.00324
# NO_VENTA-WOM-CONVERGENCIA_DIFERENTE_TITULAR                        0.00324
# NO_VENTA-VIRGIN-NO_APROBADO_CARTERA_TIGO                           0.00294
# NO_VENTA-TIGO_MIGRACION-NO_CUENTA_CON_DIRECCION                    0.00294
# PYMES_UNE_VTAS-NO_VENTA-VENTA_FUTURA                               0.00265
# NO_VENTA-AVANTEL-LO_PENSARA_O_CONSULTARA                           0.00236
# NO_VENTA-WOM-MEJOR_OFERTA                                          0.00236
# NO_VENTA-VIRGIN-DECIDE_ACERCARSE_MEJOR_A_UNA_OFICI                 0.00206
# NO_VENTA-VIRGIN-DESEA_OFERTA_NO_DISPONIBLE                         0.00206
# NO_VENTA-VIRGIN-NO_CUENTA_CON_SIM_ACTIVA_PARA_PORT                 0.00206
# PYMES_UNE_VTAS-NO_VENTA-NO_APROBADO_CARTERA                        0.00206
# PYMES_UNE_VTAS-NO_VENTA-TARIFA_ALTA                                0.00177
# NO_VENTA-VIRGIN-CONVERGENCIA_DIFERENTE_TITULAR                     0.00177
# PYMES_UNE_VTAS-NO_VENTA-LO_TOMARA_POR_OFICINA_O_PAP                0.00177
# PYMES_UNE_VTAS-NO_VENTA-QUEDARA_A_NOMBRE_DE_OTRO                   0.00147
# NO_VENTA-AVANTEL-NO_APROBADO_CARTERA_TIGO                          0.00147
# NO_VENTA-VIRGIN-NO_CUENTA_CON_DOCUMENTO_VALIDO                     0.00147
# NO_VENTA-VIRGIN-TARIFA_ALTA                                        0.00118
# PYMES_UNE_VTAS-NO_VENTA-NO_PASA_EVIDENTE                           0.00118
# PYMES_UNE_VTAS-NO_VENTA-NO_SE_AJUSTA_A_LAS_CARACTERISTICAS         0.00088
# VENTA-TELEVISION_+_MOVIL                                           0.00088
# PYMES_NO_VENTA_TIGO_SOLICITA_PROMO_SMS                             0.00088
# NO_VENTA-VIRGIN-NO_CUENTA_CON_DIRECCION                            0.00088
# PYMES_NO_VENTA_TIGO_CLIENTE_DESEA_OFERTA_NO_DISPON                 0.00088
# PYMES_NO_VENTA_TIGO_NO_CUENTA_CON_DOCUMENTO_VALIDO                 0.00088
# PYMES_NO_VENTA_TIGO_DESEA_PLAN_DE_SOLO_DATOS_O_MIN                 0.00088
# NO_VENTA-VIRGIN-QUEDARA_A_NOMBRE_DE_OTRO                           0.00088
# PYMES_UNE_VTAS-NO_VENTA-MEJOR_OFERTA                               0.00059
# PYMES_UNE_VTAS-NO_VENTA-PAGO_PARCIAL_DE_CONEXION                   0.00059
# PYMES_NO_VENTA_TIGO_NO_CUENTA_CON_SIM_ACTIVA_PARA_                 0.00059
# PYMES_NO_VENTA_TIGO_LO_PENSARA_O_CONSULTARA                        0.00059
# NO_VENTA-VIRGIN-MEJOR_OFERTA                                       0.00059
# NO_VENTA-NO_CUMPLE_PRIMERA_FACTURA_EXISTENTE                       0.00059
# PYMES_NO_VENTA_TIGO_USUARIO_NO_CUENTA_CON_EL_PRIME                 0.00059
# PYMES_UNE_VTAS-NO_VENTA-RESTRICCION_REDCO                          0.00059
# PYMES_NO_VENTA_TIGO_SALDOS_PENDIENTES_EN_HOME                      0.00059
# VENTA-TELEFONIA                                                    0.00059
# NO_VENTA-AVANTEL-DESEA_OFERTA_NO_DISPONIBLE                        0.00059
# PYMES_UNE_VTAS-NO_VENTA-CLIENTE_SIN_NIP                            0.00059
# NO_VENTA-AVANTEL-DECIDE_ACERCARSE_MEJOR_A_UNA_OFIC                 0.00059
# PYMES_NO_VENTA_TIGO_FECHA_DE_EXPEDICION_DE_LA_CEDU                 0.00059
# PYMES_NO_VENTA_TIGO_NO_APROBADO_CARTERA                            0.00059
# PYMES_NO_VENTA_TIGO_CONVERGENCIA_DIFERENTE_TITULAR                 0.00029
# NO_VENTA-AVANTEL-CONVERGENCIA_DIFERENTE_TITULAR                    0.00029
# PYMES_NO_VENTA_TIGO_MEJOR_OFERTA                                   0.00029
# PYMES_NO_VENTA_TIGO_DECIDE_ACERCARSE_MEJOR_A_UNA_O                 0.00029
# NO_VENTA-VIRGIN-NO_TIENE_FECHA_DE_EXPEDICION_DE_LA                 0.00029
# NO_VENTA-AVANTEL-MEJOR_OFERTA                                      0.00029
# PYMES_UNE_VTAS-NO_VENTA-INCONFORME_CON_CONTENIDO                   0.00029
# NO_VENTA-CLARO-ZONA_ROJA                                           0.00029
# NO_VENTA-AVANTEL-QUEDARA_A_NOMBRE_DE_OTRO                          0.00029
# PYMES_NO_VENTA_TIGO_TARIFA_ALTA                                    0.00029
# NO_VENTA-OTROS-ZONA_ROJA                                           0.00029
# PYMES_UNE_VTAS-NO_VENTA-PAGO_ANTICIPADO_CARGO_BASICO_PACB          0.00029
# NO_VENTA-MOVISTAR-ZONA_ROJA                                        0.00029
# Name: proportion, dtype: float64

# %%
BD_funnel_consol['efectivos'] = np.where((BD_funnel_consol['Nivel1'] =='VENTA') , 'SI','NO')

# %%
print(BD_funnel_consol['Estado'].value_counts(dropna=False))
print()
print(BD_funnel_consol['Estado'].value_counts(True,dropna=False)*100)
# Out:
# Estado
# NaN           285457
# Atendido       52946
# Abandonado      1244
# Name: count, dtype: int64
#
# Estado
# NaN          84.04520
# Atendido     15.58854
# Abandonado    0.36626
# Name: proportion, dtype: float64

# %%
BD_funnel_consol['contacto_efectivo'] = np.where((BD_funnel_consol['Estado'] =='Atendido') , 'SI','NO')

# %%
BD_funnel_consol['llamada_abandonada'] = np.where((BD_funnel_consol['CodFinalizacion'] =='Abandonada') , 'SI','NO')

# %% [markdown]
# **Construcción del Funnel de Conversión Completo**
#
# Mapear el funnel desde N1 hasta N2 por cada canal.Calcular:<br>
#
# *	Tasas de conversión y calidad por medio.
# *	Tiempo promedio de llamada por medio.
# *	Volumen de clientes en cada nivel del funnel.
# *	Proponer otros indicadores y su respectivo análisis.
#
#
# **Visualización gerencial**
#
# Construir un dashboard o reporte visual con:<br>
#
# *	Funnel de conversión por canal.
# *	KPIs clave: tasa de conversión, tiempo de conversión, tasa de abandono.
# *	Comparación entre medios.
# *	Insights sobre desviaciones o comportamientos atípicos.

# %%
print(BD_funnel_consol.shape)
BD_funnel_consol.head()
# Out:
# (339647, 44)
#     CALLID    Telefono         Nombre usuario               Id Oferta  \
# 0  2515240  3172127900     UsuarioMultioferta      Multiofertas Brand
# 1  2515241  3054004532  LuisFelipeSalgadoMarn  Home Trio BTS Original
# 2  2515242  3113336842     UsuarioMultioferta      Multiofertas Brand
# 3  2515243  3163739622              Valentina       Multioferta Brand
# 4  2515244  3197425550     UsuarioMultioferta      Multiofertas Brand
#
#                                   Descripcion Oferta Descripcion Opcional  \
# 0  sem/co-post-mkt_search_performance_pospago_mul...               search
# 1  sem/co-home-mkt_search_performance_home_triodi...               search
# 2  sem/co-post-mkt_search_performance_pospago_mul...               search
# 3  sem/co-post-mkt_search_performance_pospago_mul...               search
# 4  sem/co-post-mkt_search_performance_pospago_mul...               search
#
#           Codigo de resultado Fecha efectiva Hora efectiva  Duracion  \
# 0  Answering Machine Detected     2023-08-14      12:58:57  34.00000
# 1                     CUELGUE     2023-08-14      12:28:54  25.00000
# 2                     FACTURA     2023-08-14      11:56:59 183.00000
# 3              BLENDING MOVIL     2023-08-14      11:57:01 939.00000
# 4  Answering Machine Detected     2023-08-14      12:59:46  18.00000
#
#                 Asesor         Jobname Correo  \
# 0                  NaN  UNE_TELLAMAGEN    NaN
# 1  lmosqmos_tellamagen  UNE_TELLAMAGEN    NaN
# 2  lhernagr_tellamagen  UNE_TELLAMAGEN    NaN
# 3  ycanaver_tellamagen  UNE_TELLAMAGEN    NaN
# 4                  NaN  UNE_TELLAMAGEN    NaN
#
#                                 DescSolicitudCliente Fecha primer intento  \
# 0  Cj0KCQjwoeemBhCfARIsADR2QCvgkvrVBodA3LSKjpK2Nt...           2023-08-14
# 1  Cj0KCQjwoeemBhCfARIsADR2QCsdaiD7tx9vHLPnCjRXEn...           2023-08-14
# 2  Cj0KCQjwoeemBhCfARIsADR2QCsm4hrff2Um6tH9S023Fw...           2023-08-14
# 3  Cj0KCQjwoeemBhCfARIsADR2QCtuhWk-5dyWCS2XpEThw3...           2023-08-14
# 4  Cj0KCQjwoeemBhCfARIsADR2QCtN6mOC1kp9J_HKz1Iw3q...           2023-08-14
#
#   Hora primer intento Gerencia  Negocio Medio Pauta    fecha_registro_2  \
# 0            11:56:14  Digital  Pospago        SEM  2023-08-14 11:56:05
# 1            11:56:27  Digital  Hogares        SEM  2023-08-14 11:56:08
# 2            11:56:59  Digital  Pospago        SEM  2023-08-14 11:56:17
# 3            11:57:01  Digital  Pospago        SEM  2023-08-14 11:56:47
# 4            11:57:11  Digital  Pospago        SEM  2023-08-14 11:57:06
#
#   anio_mes  ANI Asesor_call  Duracion_Seg Piloto Nivel1 Nivel2 Nivel3  Nivel4  \
# 0   202308  NaN         NaN           NaN    NaN    NaN    NaN    NaN     NaN
# 1   202308  NaN         NaN           NaN    NaN    NaN    NaN    NaN     NaN
# 2   202308  NaN         NaN           NaN    NaN    NaN    NaN    NaN     NaN
# 3   202308  NaN         NaN           NaN    NaN    NaN    NaN    NaN     NaN
# 4   202308  NaN         NaN           NaN    NaN    NaN    NaN    NaN     NaN
#
#   CodFinalizacion Estado DNIS Negocio_call Linea   BU Gerencia_call Origen  \
# 0             NaN    NaN  NaN          NaN   NaN  NaN           NaN    NaN
# 1             NaN    NaN  NaN          NaN   NaN  NaN           NaN    NaN
# 2             NaN    NaN  NaN          NaN   NaN  NaN           NaN    NaN
# 3             NaN    NaN  NaN          NaN   NaN  NaN           NaN    NaN
# 4             NaN    NaN  NaN          NaN   NaN  NaN           NaN    NaN
#
#   fecha_2 anio_mes_2 Medio_Pauta_2 Medio_Pauta_pareto efectivos  \
# 0     NaT        NaN           sem                sem        NO
# 1     NaT        NaN           sem                sem        NO
# 2     NaT        NaN           sem                sem        NO
# 3     NaT        NaN           sem                sem        NO
# 4     NaT        NaN           sem                sem        NO
#
#   contacto_efectivo llamada_avandonada
# 0                NO                 NO
# 1                NO                 NO
# 2                NO                 NO
# 3                NO                 NO
# 4                NO                 NO

# %%
print(BD_funnel_consol['Descripcion Opcional'].value_counts(dropna=False))
print()
print(BD_funnel_consol['Descripcion Opcional'].value_counts(True,dropna=False)*100)
# Out:
# Descripcion Opcional
# search                     167527
# Facebookleads               52890
# Portal                      46677
# NaN                         19361
# masiv                       16345
# gdn                          8843
# Ecommerce Home               6803
# Lead_form_sem                4543
# facebook                     4457
# Walmeric                     2742
# portal                       2520
# portal_ecommerce             2184
# Desborde IVR - Movil         1512
# Abandono VTEX                1057
# fb                            680
# LeadGenios_Pospago            600
# whatsAppMktg                  151
# Discovery                     135
# whatsapp_chat                  96
# ig                             95
# braze                          93
# decostv                        68
# Arkeero                        40
# searchmasiv                    37
# tiktok                         26
# landing                        25
# youtube                        16
# searchlauncher                  8
# whatsapp                        8
# launcher                        8
# google                          8
# google_sem                      7
# botwtpventas                    6
# 1:55                            6
# taptap                          4
# searchbraze                     4
# 0:38                            4
# searchpardot                    3
# Cmgroup_Home                    3
# Desborde IVR - Home             3
# 0:12                            3
# peoplemedia                     3
# dv360                           3
# searchsender-tigo               2
# Millicom                        2
# 6:36                            2
# searchwhatsapp_chat             2
# 2:48                            2
# 1:09                            2
# searchdecostv                   2
# 6:39                            1
# 5:09                            1
# pruebanov16                     1
# 3:20                            1
# 5:06                            1
# 7:04                            1
# ecommerce                       1
# searchbot                       1
# eltiempo                        1
# 6:18                            1
# 2:09                            1
# searchchat                      1
# 5:00                            1
# 7:01                            1
# 6:00                            1
# google_sem_123                  1
# chat                            1
# 3:42                            1
# 6:54                            1
# 4:09                            1
# searchagencia-cobranzas         1
# extwebsite                      1
# bot                             1
# Pruebas                         1
# 6:45                            1
# 3:28                            1
# 4:34                            1
# searchdynamo                    1
# 6:13                            1
# Name: count, dtype: int64
#
# Descripcion Opcional
# search                    49.32386
# Facebookleads             15.57205
# Portal                    13.74280
# NaN                        5.70033
# masiv                      4.81235
# gdn                        2.60359
# Ecommerce Home             2.00296
# Lead_form_sem              1.33757
# facebook                   1.31224
# Walmeric                   0.80731
# portal                     0.74195
# portal_ecommerce           0.64302
# Desborde IVR - Movil       0.44517
# Abandono VTEX              0.31121
# fb                         0.20021
# LeadGenios_Pospago         0.17665
# whatsAppMktg               0.04446
# Discovery                  0.03975
# whatsapp_chat              0.02826
# ig                         0.02797
# braze                      0.02738
# decostv                    0.02002
# Arkeero                    0.01178
# searchmasiv                0.01089
# tiktok                     0.00766
# landing                    0.00736
# youtube                    0.00471
# searchlauncher             0.00236
# whatsapp                   0.00236
# launcher                   0.00236
# google                     0.00236
# google_sem                 0.00206
# botwtpventas               0.00177
# 1:55                       0.00177
# taptap                     0.00118
# searchbraze                0.00118
# 0:38                       0.00118
# searchpardot               0.00088
# Cmgroup_Home               0.00088
# Desborde IVR - Home        0.00088
# 0:12                       0.00088
# peoplemedia                0.00088
# dv360                      0.00088
# searchsender-tigo          0.00059
# Millicom                   0.00059
# 6:36                       0.00059
# searchwhatsapp_chat        0.00059
# 2:48                       0.00059
# 1:09                       0.00059
# searchdecostv              0.00059
# 6:39                       0.00029
# 5:09                       0.00029
# pruebanov16                0.00029
# 3:20                       0.00029
# 5:06                       0.00029
# 7:04                       0.00029
# ecommerce                  0.00029
# searchbot                  0.00029
# eltiempo                   0.00029
# 6:18                       0.00029
# 2:09                       0.00029
# searchchat                 0.00029
# 5:00                       0.00029
# 7:01                       0.00029
# 6:00                       0.00029
# google_sem_123             0.00029
# chat                       0.00029
# 3:42                       0.00029
# 6:54                       0.00029
# 4:09                       0.00029
# searchagencia-cobranzas    0.00029
# extwebsite                 0.00029
# bot                        0.00029
# Pruebas                    0.00029
# 6:45                       0.00029
# 3:28                       0.00029
# 4:34                       0.00029
# searchdynamo               0.00029
# 6:13                       0.00029
# Name: proportion, dtype: float64

# %% [markdown]
# #### Guardar base funnel consolidada

# %%
BD_funnel_consol['CALLID'].nunique()
# Out:
# 339647

# %% [markdown]
# ![dashboard](dashboard.png)

# %% [markdown]
# ### solo una muestra para poder subirlo a github

# %%
BD_funnel_consol.head(20).to_csv(r"./funnel_consolidado.csv", index=False)

# %% [markdown]
# #### **Parte 3 – Uso SQL**
#
# Para esta sección no es necesaria hacer presentación. **Solamente se requiere enviar su solución. Los datos en las tablas descritas a continuación, son de “libre creación”.**
# Evaluación SQL (Estándar)
#
# Sean las siguientes tablas de una base de datos de una corredora de propiedades:
# 1.	Arrendatario (RUT, Nombre, Apellido)
# 2.	Arrienda (RUT, Id_casa,Deuda) Ojo: Deuda >=0 (si es 0, no hay deuda)
# 3.	Teléfonos (RUT, Telefono)
# 4.	Dueño (RUT, Nombre, Apellido)
# 5.	Casa (Id_casa, RUT, Nro,Calle, Comuna)<br>
#
# ```sql
# CREATE TABLE Arrendatario (
#     RUT VARCHAR(20) PRIMARY KEY,
#     Nombre VARCHAR(100) NOT NULL,
#     Apellido VARCHAR(100) NOT NULL
# );
#
# CREATE TABLE Dueño (
#     RUT VARCHAR(20) PRIMARY KEY,
#     Nombre VARCHAR(100) NOT NULL,
#     Apellido VARCHAR(100) NOT NULL
# );
#
# CREATE TABLE Casa (
#     Id_casa INT PRIMARY KEY,
#     RUT VARCHAR(20) NOT NULL,
#     Nro VARCHAR(10) NOT NULL,
#     Calle VARCHAR(100) NOT NULL,
#     Comuna VARCHAR(100) NOT NULL,
#     FOREIGN KEY (RUT) REFERENCES Dueño(RUT)
# );
#
# CREATE TABLE Arrienda (
#     RUT VARCHAR(20) NOT NULL,
#     Id_casa INT NOT NULL,
#     Deuda DECIMAL(12,2) NOT NULL CHECK (Deuda >= 0),
#     PRIMARY KEY (RUT, Id_casa),
#     FOREIGN KEY (RUT) REFERENCES Arrendatario(RUT),
#     FOREIGN KEY (Id_casa) REFERENCES Casa(Id_casa)
# );
#
# CREATE TABLE Telefonos (
#     RUT VARCHAR(20) NOT NULL,
#     Telefono VARCHAR(20) NOT NULL,
#     PRIMARY KEY (RUT, Telefono),
#     FOREIGN KEY (RUT) REFERENCES Arrendatario(RUT)
# );
# ```
# Al respecto, conteste las siguientes preguntas construyendo las sentencias SQL que corresponda:<br>
#
# 1.	Los arrendatarios que arriendan la casa ubicada en la calle Carrera nº 1024, Santiago.
#
# ```sql
# SELECT a.RUT, a.Nombre, a.Apellido
# FROM Arrendatario a
# JOIN Arrienda ar ON a.RUT = ar.RUT
# JOIN Casa c ON ar.Id_casa = c.Id_casa
# WHERE c.Calle = 'Carrera' AND c.Nro = 1024 AND c.Comuna = 'Santiago';
# ```
#
# 2.	¿Cuánto le deben a María Pérez?
#
#
# ```sql
# SELECT SUM(ar.Deuda) AS Total_Deuda
# FROM Dueño d
# JOIN Casa c ON d.RUT = c.RUT
# JOIN Arrienda ar ON c.Id_casa = ar.Id_casa
# WHERE d.Nombre = 'María' AND d.Apellido = 'Pérez';
# ```
# 3.	¿Cuál es la deuda total para cada dueño?
#
# ```sql
# SELECT d.RUT, d.Nombre, d.Apellido, SUM(ar.Deuda) AS Total_Deuda
# FROM Dueño d
# JOIN Casa c ON d.RUT = c.RUT
# JOIN Arrienda ar ON c.Id_casa = ar.Id_casa
# GROUP BY d.RUT, d.Nombre, d.Apellido;
# ```
# 4.	Liste todas las personas de la base de datos
#
# ```sql
# SELECT RUT, Nombre, Apellido FROM Arrendatario
# UNION
# SELECT RUT, Nombre, Apellido FROM Dueño;
# ```
#
# 5.	Indique los dueños que poseen tres o más casas.
#
# ```sql
# SELECT d.RUT, d.Nombre, d.Apellido, COUNT(c.Id_casa) AS Cantidad_Casas
# FROM Dueño d
# JOIN Casa c ON d.RUT = c.RUT
# GROUP BY d.RUT, d.Nombre, d.Apellido
# HAVING COUNT(c.Id_casa) >= 3;
# ```
#
# 6.	Liste los dueños que tengan deudores en todas sus casas.
#
# ```sql
# SELECT d.RUT, d.Nombre, d.Apellido
# FROM Dueño d
# JOIN Casa c ON d.RUT = c.RUT
# LEFT JOIN Arrienda ar ON c.Id_casa = ar.Id_casa
# GROUP BY d.RUT, d.Nombre, d.Apellido
# HAVING SUM(CASE WHEN ar.Deuda = 0 OR ar.Deuda IS NULL THEN 1 ELSE 0 END) = 0;
# ```
#
# 7.	Entregue estadísticas sobre los arrendatarios por casa. Entregue:
# •	El promedio
# •	La varianza
# •	El máximo
# •	El mínimo.
# •	La moda.
# •	La mediana.
#
# ```sql
# SELECT
#     c.Id_casa,
#     COUNT(ar.RUT) AS cantidad_arrendatarios,
#     AVG(ar.Deuda) AS promedio_deuda,
#     VARIANCE(ar.Deuda) AS varianza_deuda,
#     MAX(ar.Deuda) AS max_deuda,
#     MIN(ar.Deuda) AS min_deuda,
#     -- Moda: valor más frecuente de la deuda
#     (SELECT ar2.Deuda
#      FROM Arrienda ar2
#      WHERE ar2.Id_casa = c.Id_casa
#      GROUP BY ar2.Deuda
#      ORDER BY COUNT(*) DESC
#      LIMIT 1) AS moda_deuda,
#     -- Mediana: valor central de la deuda
#     (SELECT AVG(sub.Deuda) FROM (
#             SELECT ar3.Deuda
#             FROM Arrienda ar3
#             WHERE ar3.Id_casa = c.Id_casa
#             ORDER BY ar3.Deuda
#             LIMIT 2 - (SELECT COUNT(*) FROM Arrienda ar4 WHERE ar4.Id_casa = c.Id_casa) % 2
#             OFFSET (SELECT (COUNT(*) - 1) / 2 FROM Arrienda ar5 WHERE ar5.Id_casa = c.Id_casa)
#     ) sub) AS mediana_deuda
# FROM Casa c
# LEFT JOIN Arrienda ar ON c.Id_casa = ar.Id_casa
# GROUP BY c.Id_casa;
# ```
#
#
#
# #### **Evaluación PL/SQL (Oracle)**
#
# ### 1.	Explique la función NVL. ¿Es mejor usar un NVL que un Case When? Explique su respuesta.
#
#  La función `NVL(expr1, expr2)` en Oracle retorna `expr2` si `expr1` es `NULL`; de lo contrario, retorna `expr1`. Es útil para reemplazar valores nulos por un valor por defecto.
#
#  **¿Es mejor usar NVL que un CASE WHEN?**
#
#  Para reemplazar nulos, `NVL` es más simple y legible que `CASE WHEN expr IS NULL THEN ... ELSE ... END`. Sin embargo, `CASE WHEN` es más flexible para condiciones complejas. Si solo necesitas reemplazar nulos, `NVL` es preferible por claridad y rendimiento.
#
#
# ### 2.	Explique la función Left Join. En que casos es mas relevante usar un Left Join, en vez de un Inner Join.
#
# **Función LEFT JOIN**
#
# Un `LEFT JOIN` retorna todas las filas de la tabla izquierda y las filas coincidentes de la tabla derecha. Si no hay coincidencia, los valores de la tabla derecha serán `NULL`.
#
#  **¿Cuándo usar LEFT JOIN en vez de INNER JOIN?**
#
#  Usa `LEFT JOIN` cuando necesitas conservar todas las filas de la tabla izquierda, incluso si no hay coincidencia en la tabla derecha. Por ejemplo, para listar todos los clientes y sus pedidos (si existen), mostrando clientes sin pedidos.
#
#
#
# ### 3.	Explique la función row_number() Over (Partition by … Order by…). Danos un ejemplo en el cual es funcional esta función.
#
# **Función ROW_NUMBER() OVER (PARTITION BY ... ORDER BY ...)**
#     Asigna un número secuencial a cada fila dentro de un grupo definido por `PARTITION BY`, ordenado por `ORDER BY`.
#     **Ejemplo funcional:**
#     Obtener el pedido más reciente por cliente:
#
#     ```sql
#     SELECT *
#     FROM (
#       SELECT
#          cliente_id,
#          pedido_id,
#          fecha_pedido,
#          ROW_NUMBER() OVER (PARTITION BY cliente_id ORDER BY fecha_pedido DESC) AS rn
#       FROM pedidos
#     ) t
#     WHERE rn = 1;
#     ```
#
#     Así obtienes el último pedido de cada cliente.
#
# ### 4.	Explique que es un Cursor y cuando son Implícitos y Explícitos
#
# **Cursor**
#     Un cursor es un mecanismo para recorrer fila por fila el resultado de una consulta en bases de datos.
#     - **Implícitos:** Se gestionan automáticamente, por ejemplo, en sentencias `SELECT INTO` o `UPDATE`.
#     - **Explícitos:** El programador los declara y controla (abrir, recorrer, cerrar), útiles para procesar resultados fila a fila en PL/SQL.
#
#
# ### 5.	¿Crees que desde Oracle puedes crear una ETL y que sea funcional? Justifica tu respuesta
#
# Sí, Oracle permite crear procesos ETL usando PL/SQL, procedimientos almacenados, funciones, triggers y herramientas como Oracle Data Integrator. Puedes extraer datos, transformarlos y cargarlos en tablas destino, automatizando procesos complejos y asegurando integridad y rendimiento.
#
# **Ventajas de usar Oracle para ETL:**
#
# **Integración nativa:**
# ODI se integra de forma eficiente con las bases de datos Oracle.
#
# **Escalabilidad:**
#
# Oracle ofrece soluciones para manejar grandes volúmenes de datos, tanto en sus productos on-premise como en la nube. <br>
#
# **Reutilización de componentes:**
# ODI permite reutilizar componentes y transformaciones, lo que agiliza el desarrollo y mantenimiento de los flujos ETL. <br>
#
# **Flexibilidad:**
# Oracle proporciona diferentes opciones para construir flujos ETL, adaptándose a las necesidades específicas de cada proyecto.
#
# **Conectividad:**
#
# Oracle ofrece una amplia variedad de conectores para diversas fuentes y destinos de datos. <br>
#
# En resumen, Oracle ofrece herramientas y funcionalidades sólidas para crear soluciones ETL funcionales y eficientes, con opciones para adaptarse a diferentes necesidades y entornos.

# %% [markdown]
# ## conclusiones Finales:
#
# * Mejor modelo por F1 score Random forest Classifier(RF) 64,99%

# %% [markdown]
# ## Fin
#
# -------
